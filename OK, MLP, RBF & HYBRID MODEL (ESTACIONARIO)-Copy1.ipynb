# %%
import geostatspy.GSLIB as GSLIB                          # Utilidades GSLIB y funciones envueltas
import geostatspy.geostats as geostats                    # GSLIB convertido a Python
import os                                                 # Para configurar el directorio de trabajo
import numpy as np                                        # Biblioteca de funciones matemáticas
import pandas as pd                                       # Biblioteca para manipulación de marcos de datos
import matplotlib.pyplot as plt                           # Biblioteca para salida gráfica
import scipy.stats                                        # Biblioteca de resumenes estadísticos y matemáticos
import random as rand
from sklearn.metrics import r2_score
import geostatspy.geostats as geostats                    # GSLIB convertido a Python
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras import layers
from keras.optimizers import RMSprop 
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import seaborn as sns
plt.rcParams.update(plt.rcParamsDefault)
import pygeostat as gs
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
from RBFN import *
plt.rcParams.update(plt.rcParamsDefault)

os.chdir("C:/Users/nubem/Documents/NUBEMINERA_2020/GSLIB_FOLDER") # ruta de ejecutables de GSLIB

# %%
nx = 100; ny = 50; cell_size=10                             # grid number of cells and cell size
xmin = 0; ymin =0;                                          # grid origin
xmax = 1000; ymax = 500    # calculate the extent of model
seed = 172763650
vmin = 0; vmax = 1; cmap = plt.cm.jet                     # color min and max and using the plasma color map
va_mean = 2; va_stdev = 0.55; va_cmin = 0; va_cmax = 4
var = GSLIB.make_variogram(nug=0.0,nst=1,it1=1,cc1=1.0,azi1=0,hmaj1=250,hmin1=250)
V = GSLIB.sgsim_uncond(1,nx,ny,cell_size,seed,var,"u")
V = GSLIB.affine(V,va_mean,va_stdev)
df_zko = pd.DataFrame(V)
df11 = df_zko.stack().reset_index().rename(columns={"level_0": "Elevation[Z]", "level_1": "Este[X]", 0:"V"})
x = df11["Elevation[Z]"].iloc[::-1].reset_index()
df11["Elevation[Z]"] = x["Elevation[Z]"]
##############################################################################################################
grid_x = np.linspace(0,500, num=50, endpoint=False) #Coord. de origen x, coord. de termino x, nª de celdas x.
grid_y = np.linspace(0,1000, num=100, endpoint=False) #Coord. de origen y, coord. de termino y, nª de celdas y.
gy = np.array(grid_y) #conversión a un array de numpy 
gx = np.array(grid_x) #conversión a un array de numpy 
yg, xg = np.meshgrid(grid_x, grid_y, indexing='ij') #Creación de la grilla (intersecciones en yg; xg)
x_g = xg.ravel() #aplanamiento de xg
y_g = yg.ravel() #aplanamiento de yg
d = {'X': x_g, 'Y': y_g} #Columnas con coordenadas X e Y.
df = pd.DataFrame(data=d) #Creación del dataframe 
h = df["Y"].iloc[::-1].reset_index()
df["Y"] = h["Y"]
df["V"] = df11["V"] #Traspaso de la columna VA al nuevo DataFrame.
df.to_csv("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Hybrid_model_test_2023/data_test_2.csv")
#valores_x = [50, 350,650,8950]
valores_x = [50,250,350,450,550,650,750,950]
df_filtrado = df[df['X'].isin(valores_x)].copy()

for x in [950]:
    df_filtrado = df_filtrado.loc[~((df_filtrado['X'] == x) & ((df_filtrado['Y'] <= 300)))]
    
for x in [50]:
    df_filtrado = df_filtrado.loc[~((df_filtrado['X'] == x) & ((df_filtrado['Y'] <= 300)))]

df_filtrado.to_csv("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Hybrid_model_test_2023/sample_dh_test2.csv")

# %%
marker_size=16
fig = plt.figure(figsize=(16,4))
plt.subplot(121)
plt.scatter(df["X"], df["Y"], marker_size, df["V"], cmap = plt.cm.jet, marker="s")
#plt.title("SGSIM+Affine Correction", fontsize=20)
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
plt.subplot(122)
plt.scatter(df_filtrado["X"], df_filtrado["Y"], marker_size,df_filtrado["V"], cmap = cmap, marker="s")
#plt.title("Drillholes spacing 150 m", fontsize=20)
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
#plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Figuras paper 1/figure_2.png", dpi=300)
plt.show()

# %%
df["V"].min()
# Out:
# 0.09669299955415167

# %% [markdown]
# # Modelo MLP:

# %%
X = df_filtrado.drop(["V"],axis=1) 
y = df_filtrado["V"]
X.head()
# Out:
#         X      Y
# 5    50.0  490.0
# 25  250.0  490.0
# 35  350.0  490.0
# 45  450.0  490.0
# 55  550.0  490.0

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.10,random_state=17276)

# %%
X_train = pd.DataFrame(StandardScaler().fit_transform(X_train))
X_test = pd.DataFrame(StandardScaler().fit_transform(X_test))
X_train.rename(columns={0:"X", 1:"Y"}, inplace=True)
X_test.rename(columns={0:"X", 1:"Y"}, inplace=True)

# %%
network = models.Sequential()
network.add(layers.Dense(64, activation='relu', input_shape=X_train.shape[1:]))
network.add(layers.Dense(64, activation='relu'))
network.add(layers.Dense(64, activation='relu'))
network.add(layers.Dense(64, activation='relu'))
network.add(layers.Dense(1)) 
network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                192
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 12737 (49.75 KB)
# Trainable params: 12737 (49.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
network.compile(
   loss = 'mean_squared_error', 
   optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
)

# %%
history = network.fit(X_train, y_train, epochs=1000, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/1000
# 10/10 [==============================] - 2s 61ms/step - loss: 1.6917 - val_loss: 0.9698
# Epoch 2/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6045 - val_loss: 0.6043
# Epoch 3/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3663 - val_loss: 0.4327
# Epoch 4/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2494 - val_loss: 0.3374
# Epoch 5/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1795 - val_loss: 0.2829
# Epoch 6/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1570 - val_loss: 0.2395
# Epoch 7/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1391 - val_loss: 0.2238
# Epoch 8/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1211 - val_loss: 0.1820
# Epoch 9/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1101 - val_loss: 0.1872
# Epoch 10/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1143 - val_loss: 0.2771
# Epoch 11/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1242 - val_loss: 0.1993
# Epoch 12/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1045 - val_loss: 0.1760
# Epoch 13/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1079 - val_loss: 0.1978
# Epoch 14/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0992 - val_loss: 0.1890
# Epoch 15/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0898 - val_loss: 0.1740
# Epoch 16/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0841 - val_loss: 0.1517
# Epoch 17/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0748 - val_loss: 0.1956
# Epoch 18/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0810 - val_loss: 0.2118
# Epoch 19/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0762 - val_loss: 0.2148
# Epoch 20/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0649 - val_loss: 0.2028
# Epoch 21/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0607 - val_loss: 0.2083
# Epoch 22/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0607 - val_loss: 0.1613
# Epoch 23/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0529 - val_loss: 0.1785
# Epoch 24/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0579 - val_loss: 0.1487
# Epoch 25/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0541 - val_loss: 0.1850
# Epoch 26/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0496 - val_loss: 0.1566
# Epoch 27/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0591 - val_loss: 0.2135
# Epoch 28/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0707 - val_loss: 0.1615
# Epoch 29/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0780 - val_loss: 0.1817
# Epoch 30/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0874 - val_loss: 0.1351
# Epoch 31/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0731 - val_loss: 0.1487
# Epoch 32/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0610 - val_loss: 0.1586
# Epoch 33/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0523 - val_loss: 0.1651
# Epoch 34/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0482 - val_loss: 0.1715
# Epoch 35/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0561 - val_loss: 0.1624
# Epoch 36/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0560 - val_loss: 0.2048
# Epoch 37/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0511 - val_loss: 0.1448
# Epoch 38/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0517 - val_loss: 0.1678
# Epoch 39/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0523 - val_loss: 0.1651
# Epoch 40/1000
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0477 - val_loss: 0.1643
# Epoch 41/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0484 - val_loss: 0.1425
# Epoch 42/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0401 - val_loss: 0.1364
# Epoch 43/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0435 - val_loss: 0.1689
# Epoch 44/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0563 - val_loss: 0.1429
# Epoch 45/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0479 - val_loss: 0.1465
# Epoch 46/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0446 - val_loss: 0.1694
# Epoch 47/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0454 - val_loss: 0.1409
# Epoch 48/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0473 - val_loss: 0.1560
# Epoch 49/1000
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0553 - val_loss: 0.1899
# Epoch 50/1000
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0656 - val_loss: 0.1416
# Epoch 51/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0492 - val_loss: 0.1490
# Epoch 52/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0434 - val_loss: 0.1849
# Epoch 53/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0498 - val_loss: 0.1635
# Epoch 54/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0449 - val_loss: 0.1452
# Epoch 55/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0460 - val_loss: 0.2014
# Epoch 56/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0462 - val_loss: 0.1676
# Epoch 57/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0553 - val_loss: 0.1561
# Epoch 58/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0442 - val_loss: 0.1435
# Epoch 59/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0346 - val_loss: 0.1496
# Epoch 60/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0346 - val_loss: 0.1355
# Epoch 61/1000
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0392 - val_loss: 0.1647
# Epoch 62/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0415 - val_loss: 0.1369
# Epoch 63/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0460 - val_loss: 0.1651
# Epoch 64/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0457 - val_loss: 0.1785
# Epoch 65/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0551 - val_loss: 0.1698
# Epoch 66/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0496 - val_loss: 0.1752
# Epoch 67/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0529 - val_loss: 0.1406
# Epoch 68/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0445 - val_loss: 0.1432
# Epoch 69/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0452 - val_loss: 0.1506
# Epoch 70/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0481 - val_loss: 0.1674
# Epoch 71/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0400 - val_loss: 0.1734
# Epoch 72/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0368 - val_loss: 0.1830
# Epoch 73/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0450 - val_loss: 0.1224
# Epoch 74/1000
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0373 - val_loss: 0.1459
# Epoch 75/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0437 - val_loss: 0.1518
# Epoch 76/1000
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0369 - val_loss: 0.1964
# Epoch 77/1000
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0495 - val_loss: 0.1577
# Epoch 78/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0445 - val_loss: 0.1733
# Epoch 79/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0456 - val_loss: 0.1643
# Epoch 80/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0389 - val_loss: 0.1525
# Epoch 81/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0445 - val_loss: 0.1219
# Epoch 82/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0424 - val_loss: 0.1539
# Epoch 83/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0347 - val_loss: 0.1458
# Epoch 84/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0333 - val_loss: 0.1561
# Epoch 85/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0374 - val_loss: 0.1502
# Epoch 86/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0480 - val_loss: 0.1468
# Epoch 87/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0410 - val_loss: 0.1700
# Epoch 88/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0393 - val_loss: 0.1901
# Epoch 89/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0424 - val_loss: 0.1682
# Epoch 90/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0660 - val_loss: 0.1799
# Epoch 91/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0422 - val_loss: 0.1352
# Epoch 92/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0442 - val_loss: 0.1376
# Epoch 93/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0392 - val_loss: 0.1464
# Epoch 94/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0352 - val_loss: 0.1524
# Epoch 95/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0326 - val_loss: 0.1552
# Epoch 96/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0365 - val_loss: 0.1850
# Epoch 97/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0331 - val_loss: 0.1861
# Epoch 98/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0321 - val_loss: 0.1975
# Epoch 99/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0326 - val_loss: 0.1488
# Epoch 100/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0305 - val_loss: 0.1710
# Epoch 101/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0351 - val_loss: 0.1577
# Epoch 102/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0448 - val_loss: 0.1251
# Epoch 103/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0446 - val_loss: 0.1701
# Epoch 104/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0486 - val_loss: 0.1487
# Epoch 105/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0491 - val_loss: 0.1628
# Epoch 106/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0353 - val_loss: 0.1479
# Epoch 107/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0384 - val_loss: 0.1938
# Epoch 108/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0390 - val_loss: 0.1299
# Epoch 109/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0529 - val_loss: 0.1610
# Epoch 110/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0544 - val_loss: 0.1606
# Epoch 111/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0464 - val_loss: 0.1789
# Epoch 112/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0386 - val_loss: 0.1016
# Epoch 113/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0368 - val_loss: 0.1332
# Epoch 114/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0345 - val_loss: 0.1452
# Epoch 115/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0387 - val_loss: 0.2153
# Epoch 116/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0409 - val_loss: 0.1354
# Epoch 117/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0553 - val_loss: 0.1645
# Epoch 118/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0373 - val_loss: 0.1369
# Epoch 119/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0389 - val_loss: 0.1729
# Epoch 120/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0333 - val_loss: 0.1185
# Epoch 121/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0344 - val_loss: 0.1344
# Epoch 122/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0347 - val_loss: 0.1754
# Epoch 123/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0317 - val_loss: 0.1522
# Epoch 124/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0367 - val_loss: 0.1991
# Epoch 125/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0326 - val_loss: 0.1318
# Epoch 126/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0328 - val_loss: 0.1346
# Epoch 127/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0355 - val_loss: 0.1322
# Epoch 128/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0327 - val_loss: 0.1784
# Epoch 129/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0354 - val_loss: 0.1667
# Epoch 130/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0371 - val_loss: 0.1670
# Epoch 131/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0356 - val_loss: 0.1154
# Epoch 132/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0446 - val_loss: 0.1261
# Epoch 133/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0398 - val_loss: 0.1629
# Epoch 134/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0335 - val_loss: 0.1204
# Epoch 135/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0343 - val_loss: 0.2099
# Epoch 136/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0314 - val_loss: 0.1516
# Epoch 137/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0284 - val_loss: 0.1453
# Epoch 138/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0294 - val_loss: 0.1749
# Epoch 139/1000
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0343 - val_loss: 0.1686
# Epoch 140/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0337 - val_loss: 0.1740
# Epoch 141/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0334 - val_loss: 0.1570
# Epoch 142/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0300 - val_loss: 0.1532
# Epoch 143/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0300 - val_loss: 0.1943
# Epoch 144/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0277 - val_loss: 0.1644
# Epoch 145/1000
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0278 - val_loss: 0.1656
# Epoch 146/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0277 - val_loss: 0.1549
# Epoch 147/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0253 - val_loss: 0.1619
# Epoch 148/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0236 - val_loss: 0.1581
# Epoch 149/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0249 - val_loss: 0.1704
# Epoch 150/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0276 - val_loss: 0.1332
# Epoch 151/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0288 - val_loss: 0.1751
# Epoch 152/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0327 - val_loss: 0.1806
# Epoch 153/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0309 - val_loss: 0.1440
# Epoch 154/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0280 - val_loss: 0.2065
# Epoch 155/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0273 - val_loss: 0.1199
# Epoch 156/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0308 - val_loss: 0.1594
# Epoch 157/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0302 - val_loss: 0.2417
# Epoch 158/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0344 - val_loss: 0.1391
# Epoch 159/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0356 - val_loss: 0.1938
# Epoch 160/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0281 - val_loss: 0.1707
# Epoch 161/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0261 - val_loss: 0.1243
# Epoch 162/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0276 - val_loss: 0.1514
# Epoch 163/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0367 - val_loss: 0.1313
# Epoch 164/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0406 - val_loss: 0.1785
# Epoch 165/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0328 - val_loss: 0.1736
# Epoch 166/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0308 - val_loss: 0.1762
# Epoch 167/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0336 - val_loss: 0.1416
# Epoch 168/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0346 - val_loss: 0.1584
# Epoch 169/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0311 - val_loss: 0.1293
# Epoch 170/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0324 - val_loss: 0.1508
# Epoch 171/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0295 - val_loss: 0.1904
# Epoch 172/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0356 - val_loss: 0.1201
# Epoch 173/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0299 - val_loss: 0.1253
# Epoch 174/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0289 - val_loss: 0.1384
# Epoch 175/1000
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0298 - val_loss: 0.2017
# Epoch 176/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0283 - val_loss: 0.1047
# Epoch 177/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0276 - val_loss: 0.1295
# Epoch 178/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0326 - val_loss: 0.1092
# Epoch 179/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0277 - val_loss: 0.1477
# Epoch 180/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0258 - val_loss: 0.1437
# Epoch 181/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0284 - val_loss: 0.1649
# Epoch 182/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0265 - val_loss: 0.1368
# Epoch 183/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0348 - val_loss: 0.1788
# Epoch 184/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0335 - val_loss: 0.1500
# Epoch 185/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0292 - val_loss: 0.1700
# Epoch 186/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0301 - val_loss: 0.1376
# Epoch 187/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0297 - val_loss: 0.1277
# Epoch 188/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0290 - val_loss: 0.1761
# Epoch 189/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0268 - val_loss: 0.1876
# Epoch 190/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0280 - val_loss: 0.1728
# Epoch 191/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0287 - val_loss: 0.1767
# Epoch 192/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0301 - val_loss: 0.1958
# Epoch 193/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0283 - val_loss: 0.1589
# Epoch 194/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0264 - val_loss: 0.1389
# Epoch 195/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0273 - val_loss: 0.1933
# Epoch 196/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0254 - val_loss: 0.1530
# Epoch 197/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0223 - val_loss: 0.1724
# Epoch 198/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0227 - val_loss: 0.1478
# Epoch 199/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0243 - val_loss: 0.2130
# Epoch 200/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0228 - val_loss: 0.1591
# Epoch 201/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0281 - val_loss: 0.1522
# Epoch 202/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0241 - val_loss: 0.1724
# Epoch 203/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0246 - val_loss: 0.1775
# Epoch 204/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0227 - val_loss: 0.1143
# Epoch 205/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0225 - val_loss: 0.1414
# Epoch 206/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0221 - val_loss: 0.1606
# Epoch 207/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0247 - val_loss: 0.2177
# Epoch 208/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0270 - val_loss: 0.1678
# Epoch 209/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0265 - val_loss: 0.1787
# Epoch 210/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0286 - val_loss: 0.1998
# Epoch 211/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0331 - val_loss: 0.1155
# Epoch 212/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0287 - val_loss: 0.1665
# Epoch 213/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0278 - val_loss: 0.1319
# Epoch 214/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0264 - val_loss: 0.1182
# Epoch 215/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0251 - val_loss: 0.1632
# Epoch 216/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0239 - val_loss: 0.1791
# Epoch 217/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0315 - val_loss: 0.1386
# Epoch 218/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0252 - val_loss: 0.1629
# Epoch 219/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0247 - val_loss: 0.1826
# Epoch 220/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0260 - val_loss: 0.1771
# Epoch 221/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0268 - val_loss: 0.1352
# Epoch 222/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0288 - val_loss: 0.1321
# Epoch 223/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0316 - val_loss: 0.1510
# Epoch 224/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0290 - val_loss: 0.1421
# Epoch 225/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0257 - val_loss: 0.1219
# Epoch 226/1000
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0268 - val_loss: 0.1153
# Epoch 227/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0245 - val_loss: 0.1903
# Epoch 228/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0265 - val_loss: 0.1174
# Epoch 229/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0288 - val_loss: 0.2110
# Epoch 230/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0359 - val_loss: 0.1692
# Epoch 231/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0347 - val_loss: 0.1302
# Epoch 232/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0309 - val_loss: 0.0935
# Epoch 233/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0303 - val_loss: 0.1187
# Epoch 234/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0301 - val_loss: 0.1569
# Epoch 235/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0333 - val_loss: 0.1289
# Epoch 236/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0282 - val_loss: 0.1333
# Epoch 237/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0277 - val_loss: 0.1563
# Epoch 238/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0275 - val_loss: 0.1245
# Epoch 239/1000
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0248 - val_loss: 0.1324
# Epoch 240/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0306 - val_loss: 0.1076
# Epoch 241/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0304 - val_loss: 0.1983
# Epoch 242/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0283 - val_loss: 0.1097
# Epoch 243/1000
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0267 - val_loss: 0.1828
# Epoch 244/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0247 - val_loss: 0.1675
# Epoch 245/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0258 - val_loss: 0.1906
# Epoch 246/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0234 - val_loss: 0.1630
# Epoch 247/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0235 - val_loss: 0.1615
# Epoch 248/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0254 - val_loss: 0.1520
# Epoch 249/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0343 - val_loss: 0.1349
# Epoch 250/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0293 - val_loss: 0.1424
# Epoch 251/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0291 - val_loss: 0.2044
# Epoch 252/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0275 - val_loss: 0.1330
# Epoch 253/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0240 - val_loss: 0.1662
# Epoch 254/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0347 - val_loss: 0.0863
# Epoch 255/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0376 - val_loss: 0.1150
# Epoch 256/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0382 - val_loss: 0.1371
# Epoch 257/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0318 - val_loss: 0.1682
# Epoch 258/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0275 - val_loss: 0.1862
# Epoch 259/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0283 - val_loss: 0.1987
# Epoch 260/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0235 - val_loss: 0.1930
# Epoch 261/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0230 - val_loss: 0.1670
# Epoch 262/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0249 - val_loss: 0.1508
# Epoch 263/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0237 - val_loss: 0.1566
# Epoch 264/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0273 - val_loss: 0.1956
# Epoch 265/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0261 - val_loss: 0.1970
# Epoch 266/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0284 - val_loss: 0.1951
# Epoch 267/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0323 - val_loss: 0.3103
# Epoch 268/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0476 - val_loss: 0.1220
# Epoch 269/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0457 - val_loss: 0.1394
# Epoch 270/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0489 - val_loss: 0.1496
# Epoch 271/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0378 - val_loss: 0.1257
# Epoch 272/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0297 - val_loss: 0.1323
# Epoch 273/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0256 - val_loss: 0.1368
# Epoch 274/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0253 - val_loss: 0.1544
# Epoch 275/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0253 - val_loss: 0.1309
# Epoch 276/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0263 - val_loss: 0.1461
# Epoch 277/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0296 - val_loss: 0.1232
# Epoch 278/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0363 - val_loss: 0.0944
# Epoch 279/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0320 - val_loss: 0.1520
# Epoch 280/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0305 - val_loss: 0.1637
# Epoch 281/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0407 - val_loss: 0.1569
# Epoch 282/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0341 - val_loss: 0.1541
# Epoch 283/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0319 - val_loss: 0.1752
# Epoch 284/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0240 - val_loss: 0.1269
# Epoch 285/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0229 - val_loss: 0.1687
# Epoch 286/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0238 - val_loss: 0.1510
# Epoch 287/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0224 - val_loss: 0.1167
# Epoch 288/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0204 - val_loss: 0.1413
# Epoch 289/1000
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0209 - val_loss: 0.1433
# Epoch 290/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0216 - val_loss: 0.1609
# Epoch 291/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0276 - val_loss: 0.1770
# Epoch 292/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0244 - val_loss: 0.1717
# Epoch 293/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0216 - val_loss: 0.1177
# Epoch 294/1000
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0240 - val_loss: 0.1335
# Epoch 295/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0208 - val_loss: 0.1182
# Epoch 296/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0220 - val_loss: 0.1669
# Epoch 297/1000
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0203 - val_loss: 0.1430
# Epoch 298/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0209 - val_loss: 0.1421
# Epoch 299/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0244 - val_loss: 0.2261
# Epoch 300/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0247 - val_loss: 0.1470
# Epoch 301/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0229 - val_loss: 0.1604
# Epoch 302/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0211 - val_loss: 0.1644
# Epoch 303/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0231 - val_loss: 0.1374
# Epoch 304/1000
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0218 - val_loss: 0.1691
# Epoch 305/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0200 - val_loss: 0.1530
# Epoch 306/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0264 - val_loss: 0.1733
# Epoch 307/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0223 - val_loss: 0.1756
# Epoch 308/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0301 - val_loss: 0.1412
# Epoch 309/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0254 - val_loss: 0.1366
# Epoch 310/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0222 - val_loss: 0.1475
# Epoch 311/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0215 - val_loss: 0.1450
# Epoch 312/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0206 - val_loss: 0.1665
# Epoch 313/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0206 - val_loss: 0.1563
# Epoch 314/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0238 - val_loss: 0.1608
# Epoch 315/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0246 - val_loss: 0.1268
# Epoch 316/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0278 - val_loss: 0.1774
# Epoch 317/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0264 - val_loss: 0.2017
# Epoch 318/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0338 - val_loss: 0.2046
# Epoch 319/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0225 - val_loss: 0.1610
# Epoch 320/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0242 - val_loss: 0.1654
# Epoch 321/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0249 - val_loss: 0.1973
# Epoch 322/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0206 - val_loss: 0.1626
# Epoch 323/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0236 - val_loss: 0.1448
# Epoch 324/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0229 - val_loss: 0.0849
# Epoch 325/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0233 - val_loss: 0.1243
# Epoch 326/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0257 - val_loss: 0.1447
# Epoch 327/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0240 - val_loss: 0.1120
# Epoch 328/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0246 - val_loss: 0.1245
# Epoch 329/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0237 - val_loss: 0.1396
# Epoch 330/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0225 - val_loss: 0.1496
# Epoch 331/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0205 - val_loss: 0.1216
# Epoch 332/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0209 - val_loss: 0.1388
# Epoch 333/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0200 - val_loss: 0.1375
# Epoch 334/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0268 - val_loss: 0.1433
# Epoch 335/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0253 - val_loss: 0.1351
# Epoch 336/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0214 - val_loss: 0.1303
# Epoch 337/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0328 - val_loss: 0.2393
# Epoch 338/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0315 - val_loss: 0.1803
# Epoch 339/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0424 - val_loss: 0.1290
# Epoch 340/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0371 - val_loss: 0.1283
# Epoch 341/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0412 - val_loss: 0.1358
# Epoch 342/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0290 - val_loss: 0.1455
# Epoch 343/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0301 - val_loss: 0.1149
# Epoch 344/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0372 - val_loss: 0.1897
# Epoch 345/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0365 - val_loss: 0.1303
# Epoch 346/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0351 - val_loss: 0.1907
# Epoch 347/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0265 - val_loss: 0.0936
# Epoch 348/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0254 - val_loss: 0.1670
# Epoch 349/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0259 - val_loss: 0.1191
# Epoch 350/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0244 - val_loss: 0.1221
# Epoch 351/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0235 - val_loss: 0.1692
# Epoch 352/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0275 - val_loss: 0.1178
# Epoch 353/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0287 - val_loss: 0.1458
# Epoch 354/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0284 - val_loss: 0.1214
# Epoch 355/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0235 - val_loss: 0.1566
# Epoch 356/1000
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0266 - val_loss: 0.1502
# Epoch 357/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0240 - val_loss: 0.1816
# Epoch 358/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0303 - val_loss: 0.1627
# Epoch 359/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0216 - val_loss: 0.1481
# Epoch 360/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0239 - val_loss: 0.1546
# Epoch 361/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0278 - val_loss: 0.1735
# Epoch 362/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0274 - val_loss: 0.1946
# Epoch 363/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0243 - val_loss: 0.1374
# Epoch 364/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0221 - val_loss: 0.1656
# Epoch 365/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0252 - val_loss: 0.1487
# Epoch 366/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0232 - val_loss: 0.1465
# Epoch 367/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0236 - val_loss: 0.1697
# Epoch 368/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0246 - val_loss: 0.1330
# Epoch 369/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0246 - val_loss: 0.1254
# Epoch 370/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0290 - val_loss: 0.2194
# Epoch 371/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0279 - val_loss: 0.1572
# Epoch 372/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0219 - val_loss: 0.1294
# Epoch 373/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0202 - val_loss: 0.1877
# Epoch 374/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0207 - val_loss: 0.1231
# Epoch 375/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0200 - val_loss: 0.1548
# Epoch 376/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0236 - val_loss: 0.1360
# Epoch 377/1000
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0220 - val_loss: 0.1821
# Epoch 378/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0239 - val_loss: 0.1496
# Epoch 379/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0243 - val_loss: 0.1830
# Epoch 380/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0224 - val_loss: 0.1687
# Epoch 381/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0200 - val_loss: 0.1900
# Epoch 382/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0209 - val_loss: 0.1179
# Epoch 383/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0231 - val_loss: 0.1682
# Epoch 384/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0233 - val_loss: 0.1202
# Epoch 385/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0255 - val_loss: 0.1703
# Epoch 386/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0264 - val_loss: 0.1534
# Epoch 387/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0285 - val_loss: 0.1110
# Epoch 388/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0242 - val_loss: 0.1607
# Epoch 389/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0260 - val_loss: 0.1277
# Epoch 390/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0307 - val_loss: 0.1627
# Epoch 391/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0367 - val_loss: 0.1528
# Epoch 392/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0329 - val_loss: 0.1675
# Epoch 393/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0293 - val_loss: 0.1379
# Epoch 394/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0234 - val_loss: 0.1686
# Epoch 395/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0248 - val_loss: 0.1199
# Epoch 396/1000
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0241 - val_loss: 0.1448
# Epoch 397/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0215 - val_loss: 0.1513
# Epoch 398/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0304 - val_loss: 0.1434
# Epoch 399/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0361 - val_loss: 0.2006
# Epoch 400/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0415 - val_loss: 0.1512
# Epoch 401/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0283 - val_loss: 0.1727
# Epoch 402/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0251 - val_loss: 0.1263
# Epoch 403/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0220 - val_loss: 0.1379
# Epoch 404/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0240 - val_loss: 0.1526
# Epoch 405/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0274 - val_loss: 0.1346
# Epoch 406/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0274 - val_loss: 0.1625
# Epoch 407/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0271 - val_loss: 0.1092
# Epoch 408/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0248 - val_loss: 0.1257
# Epoch 409/1000
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0199 - val_loss: 0.1535
# Epoch 410/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0224 - val_loss: 0.1450
# Epoch 411/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0190 - val_loss: 0.1593
# Epoch 412/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0191 - val_loss: 0.1420
# Epoch 413/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0206 - val_loss: 0.1249
# Epoch 414/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0184 - val_loss: 0.1402
# Epoch 415/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0179 - val_loss: 0.1282
# Epoch 416/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0179 - val_loss: 0.1502
# Epoch 417/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0200 - val_loss: 0.1257
# Epoch 418/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0190 - val_loss: 0.1311
# Epoch 419/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0205 - val_loss: 0.1536
# Epoch 420/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0204 - val_loss: 0.1412
# Epoch 421/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0213 - val_loss: 0.1413
# Epoch 422/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0204 - val_loss: 0.1381
# Epoch 423/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0213 - val_loss: 0.1299
# Epoch 424/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0232 - val_loss: 0.1684
# Epoch 425/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0202 - val_loss: 0.1299
# Epoch 426/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0218 - val_loss: 0.1324
# Epoch 427/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0202 - val_loss: 0.1461
# Epoch 428/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0185 - val_loss: 0.1294
# Epoch 429/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0193 - val_loss: 0.1331
# Epoch 430/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0229 - val_loss: 0.1575
# Epoch 431/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0252 - val_loss: 0.1208
# Epoch 432/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0236 - val_loss: 0.1415
# Epoch 433/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0218 - val_loss: 0.1726
# Epoch 434/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0218 - val_loss: 0.1314
# Epoch 435/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0249 - val_loss: 0.1647
# Epoch 436/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0224 - val_loss: 0.1449
# Epoch 437/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0218 - val_loss: 0.1175
# Epoch 438/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0217 - val_loss: 0.1858
# Epoch 439/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0224 - val_loss: 0.1215
# Epoch 440/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0202 - val_loss: 0.1653
# Epoch 441/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0207 - val_loss: 0.1323
# Epoch 442/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0221 - val_loss: 0.1341
# Epoch 443/1000
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0199 - val_loss: 0.1418
# Epoch 444/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0170 - val_loss: 0.1377
# Epoch 445/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0191 - val_loss: 0.1381
# Epoch 446/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0175 - val_loss: 0.1423
# Epoch 447/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0178 - val_loss: 0.1528
# Epoch 448/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0207 - val_loss: 0.1362
# Epoch 449/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0208 - val_loss: 0.1328
# Epoch 450/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0188 - val_loss: 0.1197
# Epoch 451/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0200 - val_loss: 0.1668
# Epoch 452/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0216 - val_loss: 0.1428
# Epoch 453/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0226 - val_loss: 0.1446
# Epoch 454/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0303 - val_loss: 0.1284
# Epoch 455/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0222 - val_loss: 0.1477
# Epoch 456/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0213 - val_loss: 0.1530
# Epoch 457/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0217 - val_loss: 0.1061
# Epoch 458/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0202 - val_loss: 0.1365
# Epoch 459/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0206 - val_loss: 0.1479
# Epoch 460/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0204 - val_loss: 0.1391
# Epoch 461/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0238 - val_loss: 0.0950
# Epoch 462/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0216 - val_loss: 0.1293
# Epoch 463/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0223 - val_loss: 0.1022
# Epoch 464/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0232 - val_loss: 0.1477
# Epoch 465/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0260 - val_loss: 0.1188
# Epoch 466/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0236 - val_loss: 0.1393
# Epoch 467/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0245 - val_loss: 0.1431
# Epoch 468/1000
# ...
# Epoch 846/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0169 - val_loss: 0.1360
# Epoch 847/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0201 - val_loss: 0.1360
# Epoch 848/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0163 - val_loss: 0.1279
# Epoch 849/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0159 - val_loss: 0.1190
# Epoch 850/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0175 - val_loss: 0.1623
# Epoch 851/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0175 - val_loss: 0.1341
# Epoch 852/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0167 - val_loss: 0.1292
# Epoch 853/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0167 - val_loss: 0.1332
# Epoch 854/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0185 - val_loss: 0.1335
# Epoch 855/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0220 - val_loss: 0.1479
# Epoch 856/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0181 - val_loss: 0.1415
# Epoch 857/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0166 - val_loss: 0.1521
# Epoch 858/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0177 - val_loss: 0.1289
# Epoch 859/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0171 - val_loss: 0.1504
# Epoch 860/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0180 - val_loss: 0.1261
# Epoch 861/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0196 - val_loss: 0.1682
# Epoch 862/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0212 - val_loss: 0.1192
# Epoch 863/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0193 - val_loss: 0.1432
# Epoch 864/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0225 - val_loss: 0.1275
# Epoch 865/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0265 - val_loss: 0.1389
# Epoch 866/1000
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0224 - val_loss: 0.1470
# Epoch 867/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0191 - val_loss: 0.1489
# Epoch 868/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0214 - val_loss: 0.1697
# Epoch 869/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0208 - val_loss: 0.1553
# Epoch 870/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0184 - val_loss: 0.1418
# Epoch 871/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0179 - val_loss: 0.1330
# Epoch 872/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0201 - val_loss: 0.1454
# Epoch 873/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0244 - val_loss: 0.1307
# Epoch 874/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0198 - val_loss: 0.1382
# Epoch 875/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0203 - val_loss: 0.1574
# Epoch 876/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0186 - val_loss: 0.1548
# Epoch 877/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0234 - val_loss: 0.1382
# Epoch 878/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0258 - val_loss: 0.1436
# Epoch 879/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0263 - val_loss: 0.1552
# Epoch 880/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0226 - val_loss: 0.1664
# Epoch 881/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0222 - val_loss: 0.1267
# Epoch 882/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0217 - val_loss: 0.1491
# Epoch 883/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0180 - val_loss: 0.1394
# Epoch 884/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0190 - val_loss: 0.1476
# Epoch 885/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0172 - val_loss: 0.1244
# Epoch 886/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0201 - val_loss: 0.1223
# Epoch 887/1000
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0187 - val_loss: 0.1488
# Epoch 888/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0166 - val_loss: 0.1423
# Epoch 889/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0164 - val_loss: 0.1536
# Epoch 890/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0172 - val_loss: 0.1495
# Epoch 891/1000
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0165 - val_loss: 0.1505
# Epoch 892/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0182 - val_loss: 0.1455
# Epoch 893/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0182 - val_loss: 0.1381
# Epoch 894/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0257 - val_loss: 0.1525
# Epoch 895/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0218 - val_loss: 0.1894
# Epoch 896/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0202 - val_loss: 0.1364
# Epoch 897/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0204 - val_loss: 0.1664
# Epoch 898/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0216 - val_loss: 0.1381
# Epoch 899/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0200 - val_loss: 0.1666
# Epoch 900/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0181 - val_loss: 0.1328
# Epoch 901/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0182 - val_loss: 0.1646
# Epoch 902/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0195 - val_loss: 0.1243
# Epoch 903/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0212 - val_loss: 0.1644
# Epoch 904/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0210 - val_loss: 0.1493
# Epoch 905/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0207 - val_loss: 0.1260
# Epoch 906/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0189 - val_loss: 0.1199
# Epoch 907/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0178 - val_loss: 0.1474
# Epoch 908/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0166 - val_loss: 0.1291
# Epoch 909/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0166 - val_loss: 0.1301
# Epoch 910/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0156 - val_loss: 0.1264
# Epoch 911/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0163 - val_loss: 0.1299
# Epoch 912/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0150 - val_loss: 0.1337
# Epoch 913/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0157 - val_loss: 0.1262
# Epoch 914/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0166 - val_loss: 0.1582
# Epoch 915/1000
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0158 - val_loss: 0.1181
# Epoch 916/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0154 - val_loss: 0.1276
# Epoch 917/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0157 - val_loss: 0.1428
# Epoch 918/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0166 - val_loss: 0.1316
# Epoch 919/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0158 - val_loss: 0.1494
# Epoch 920/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0165 - val_loss: 0.1409
# Epoch 921/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0176 - val_loss: 0.1247
# Epoch 922/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0172 - val_loss: 0.1094
# Epoch 923/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0174 - val_loss: 0.1409
# Epoch 924/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0160 - val_loss: 0.1258
# Epoch 925/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0159 - val_loss: 0.1309
# Epoch 926/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0156 - val_loss: 0.1188
# Epoch 927/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0159 - val_loss: 0.1516
# Epoch 928/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0195 - val_loss: 0.1335
# Epoch 929/1000
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0175 - val_loss: 0.1257
# Epoch 930/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0175 - val_loss: 0.1251
# Epoch 931/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0219 - val_loss: 0.1532
# Epoch 932/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0214 - val_loss: 0.1474
# Epoch 933/1000
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0231 - val_loss: 0.1556
# Epoch 934/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0211 - val_loss: 0.1443
# Epoch 935/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0240 - val_loss: 0.1064
# Epoch 936/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0230 - val_loss: 0.1178
# Epoch 937/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0229 - val_loss: 0.1249
# Epoch 938/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0230 - val_loss: 0.1236
# Epoch 939/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0255 - val_loss: 0.1735
# Epoch 940/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0372 - val_loss: 0.1504
# Epoch 941/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0293 - val_loss: 0.1201
# Epoch 942/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0226 - val_loss: 0.1389
# Epoch 943/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0202 - val_loss: 0.1170
# Epoch 944/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0182 - val_loss: 0.1261
# Epoch 945/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0165 - val_loss: 0.1142
# Epoch 946/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0164 - val_loss: 0.1234
# Epoch 947/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0177 - val_loss: 0.1339
# Epoch 948/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0186 - val_loss: 0.1154
# Epoch 949/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0188 - val_loss: 0.1284
# Epoch 950/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0172 - val_loss: 0.1173
# Epoch 951/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0179 - val_loss: 0.1447
# Epoch 952/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0171 - val_loss: 0.1420
# Epoch 953/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0156 - val_loss: 0.1177
# Epoch 954/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0203 - val_loss: 0.1508
# Epoch 955/1000
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0190 - val_loss: 0.1160
# Epoch 956/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0218 - val_loss: 0.1617
# Epoch 957/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0194 - val_loss: 0.1364
# Epoch 958/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0206 - val_loss: 0.1358
# Epoch 959/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0226 - val_loss: 0.1496
# Epoch 960/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0241 - val_loss: 0.1315
# Epoch 961/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0201 - val_loss: 0.1409
# Epoch 962/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0194 - val_loss: 0.1402
# Epoch 963/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0207 - val_loss: 0.1384
# Epoch 964/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0203 - val_loss: 0.1177
# Epoch 965/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0200 - val_loss: 0.1744
# Epoch 966/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0198 - val_loss: 0.1308
# Epoch 967/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0177 - val_loss: 0.1152
# Epoch 968/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0178 - val_loss: 0.1120
# Epoch 969/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0175 - val_loss: 0.1203
# Epoch 970/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0169 - val_loss: 0.1138
# Epoch 971/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0189 - val_loss: 0.1405
# Epoch 972/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0192 - val_loss: 0.1137
# Epoch 973/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0214 - val_loss: 0.1326
# Epoch 974/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0205 - val_loss: 0.1431
# Epoch 975/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0247 - val_loss: 0.1361
# Epoch 976/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0305 - val_loss: 0.1503
# Epoch 977/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0263 - val_loss: 0.1520
# Epoch 978/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0272 - val_loss: 0.1513
# Epoch 979/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0257 - val_loss: 0.1647
# Epoch 980/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0258 - val_loss: 0.1603
# Epoch 981/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0209 - val_loss: 0.1567
# Epoch 982/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0199 - val_loss: 0.1416
# Epoch 983/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0181 - val_loss: 0.1429
# Epoch 984/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0182 - val_loss: 0.1348
# Epoch 985/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0168 - val_loss: 0.1509
# Epoch 986/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0158 - val_loss: 0.1435
# Epoch 987/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0152 - val_loss: 0.1405
# Epoch 988/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0152 - val_loss: 0.1701
# Epoch 989/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0148 - val_loss: 0.1361
# Epoch 990/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0148 - val_loss: 0.1596
# Epoch 991/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0147 - val_loss: 0.1327
# Epoch 992/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0141 - val_loss: 0.1635
# Epoch 993/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0157 - val_loss: 0.1333
# Epoch 994/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0159 - val_loss: 0.1522
# Epoch 995/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0151 - val_loss: 0.1601
# Epoch 996/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0157 - val_loss: 0.1475
# Epoch 997/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0146 - val_loss: 0.1486
# Epoch 998/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0158 - val_loss: 0.1509
# Epoch 999/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0147 - val_loss: 0.1547
# Epoch 1000/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0164 - val_loss: 0.1508

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Predicciones en el conjunto de entrenamiento y prueba
y_train_pred = network.predict(X_train)
y_test_pred = network.predict(X_test)

# Métricas en el conjunto de entrenamiento
r_train = np.corrcoef(y_train, y_train_pred.squeeze())[0, 1]
r2_train = r2_score(y_train, y_train_pred)
mse_train = mean_squared_error(y_train, y_train_pred)
rmse_train = np.sqrt(mse_train)
mae_train = mean_absolute_error(y_train, y_train_pred)

# Métricas en el conjunto de prueba
r_test = np.corrcoef(y_test, y_test_pred.squeeze())[0, 1]
r2_test = r2_score(y_test, y_test_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
rmse_test = np.sqrt(mse_test)
mae_test = mean_absolute_error(y_test, y_test_pred)

# Imprimir las métricas
print("Métricas en el conjunto de entrenamiento:")
print("R:", r_train)
print("R2:", r2_train)
print("MSE:", mse_train)
print("RMSE:", rmse_train)
print("MAE:", mae_train)
print("")

print("Métricas en el conjunto de prueba:")
print("R:", r_test)
print("R2:", r2_test)
print("MSE:", mse_test)
print("RMSE:", rmse_test)
print("MAE:", mae_test)
# Out:
# 10/10 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 0s/step
# Métricas en el conjunto de entrenamiento:
# R: 0.9749920609012962
# R2: 0.9499276922189481
# MSE: 0.013944332940165389
# RMSE: 0.11808612509590358
# MAE: 0.08599831042635978
#
# Métricas en el conjunto de prueba:
# R: 0.8143818781292288
# R2: 0.6618601793122534
# MSE: 0.15076839121349042
# RMSE: 0.3882890562628445
# MAE: 0.2991002106849166

# %%
grid_x = np.linspace(0,500, num=50, endpoint=False) #Coord. de origen x, coord. de termino x, nª de celdas x.
grid_y = np.linspace(0,1000, num=100, endpoint=False) #Coord. de origen y, coord. de termino y, nª de celdas y.

#En este caso la matriz es de 100 x 100 celdas.

gy = np.array(grid_y) #conversión a un array de numpy 
gx = np.array(grid_x) #conversión a un array de numpy 

yg, xg = np.meshgrid(grid_x, grid_y, indexing='ij') #Creación de la grilla (intersecciones en yg; xg)

x_g = xg.ravel() #aplanamiento de xg
y_g = yg.ravel() #aplanamiento de yg

d = {'Este[X]': x_g, 'Norte[Y]': y_g} #Columnas con coordenadas X e Y.
df2 = pd.DataFrame(data=d) #Creación del dataframe 

h = df2["Norte[Y]"].iloc[::-1].reset_index()

df2["Norte[Y]"] = h["Norte[Y]"]

df2 = pd.DataFrame(StandardScaler().fit_transform(df2))

df2.rename(columns={0:"X", 1:"Y"}, inplace=True)
df3 = df2.copy()

#df5 = df_filtrado.reset_index()


df2.head()
# Out:
#           X         Y
# 0 -1.714816  1.697749
# 1 -1.680173  1.697749
# 2 -1.645531  1.697749
# 3 -1.610888  1.697749
# 4 -1.576245  1.697749

# %%
df2.describe().T
# Out:
#     count          mean     std       min       25%  50%       75%       max
# X  5000.0  8.526513e-18  1.0001 -1.714816 -0.857408  0.0  0.857408  1.714816
# Y  5000.0 -9.094947e-17  1.0001 -1.697749 -0.866199  0.0  0.866199  1.697749

# %%
y_pred3 = network.predict(df2) #uso del modelo para un conjunto nuevo de datos de entrada (bloques zona óxido)
df2["VA_RNA"] = y_pred3
df["VA_RNA"] = df2["VA_RNA"]
df.head()
# Out:
# 157/157 [==============================] - 1s 3ms/step
#       X      Y         V    VA_RNA
# 0   0.0  490.0  1.425655  1.020032
# 1  10.0  490.0  1.398962  1.034870
# 2  20.0  490.0  1.188708  1.055312
# 3  30.0  490.0  0.992036  1.127225
# 4  40.0  490.0  0.680945  1.198920

# %%
df.describe().T
# Out:
#          count       mean         std       min         25%         50%  \
# X       5000.0  495.00000  288.689571  0.000000  247.500000  495.000000
# Y       5000.0  245.00000  144.323130  0.000000  120.000000  245.000000
# V       5000.0    2.00000    0.550055  0.096693    1.642968    2.000339
# VA_RNA  5000.0    2.01423    0.492156  0.728217    1.651205    2.003883
#
#                75%         max
# X       742.500000  990.000000
# Y       370.000000  490.000000
# V         2.364052    3.931615
# VA_RNA    2.347882    3.526094

# %%
import numpy as np
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Supongamos que tienes dos arrays con valores reales (y_true) y predicciones (y_pred)
y_true = df["V"] 
y_pred = df["VA_RNA"] 

# Calcular las métricas
r = np.corrcoef(y_true, y_pred)[0, 1]
r2 = r2_score(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mse = mean_squared_error(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)

# Imprimir los resultados
print(f"Coeficiente de correlación (R): {r:.4f}")
print(f"Coeficiente de determinación (R²): {r2:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MSE: {mse:.4f}")
print(f"MAE: {mae:.4f}")
# Out:
# Coeficiente de correlación (R): 0.4836
# Coeficiente de determinación (R²): 0.0642
# RMSE: 0.5321
# MSE: 0.2831
# MAE: 0.4148

# %%
marker_size=16
plt.figure(figsize=(8.2, 4.2))
marker_size=15
plt.scatter(df["X"], df["Y"], marker_size, df2["VA_RNA"], cmap = cmap, marker="s")
#plt.title("Hybrid Model (Kriging and Neural Network)")
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('North [Y]', fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
#plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/sample_regular_mlp_100.png", dpi=300)
plt.plot()
# Out:
# []

# %%
marker_size=16
fig = plt.figure(figsize=(16,4))
plt.subplot(121)
plt.scatter(df["X"], df["Y"], marker_size, df["V"], cmap = plt.cm.jet, marker="s")
#plt.title("SGSIM+Affine Correction", fontsize=20)
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
plt.subplot(122)
plt.scatter(df["X"], df["Y"], marker_size, df2["VA_RNA"], cmap = cmap, marker="s")
#plt.title("Hybrid Model (Kriging and Neural Network)")
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('North [Y]', fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
#plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Figuras paper 1/figure_2.png", dpi=300)
plt.show()

# %% [markdown]
# # MODELO OK:

# %%
lag000, vario000, npp000 = GSLIB.gamv_2d(df_filtrado,'X','Y','V',20,25,0,12.5,25)
lag090, vario090, npp090 = GSLIB.gamv_2d(df_filtrado,'X','Y','V',20,25,90,12.5,25)

# %%
df_filtrado["V"].var()
# Out:
# 0.2965961361135752

# %%
fig = plt.figure(figsize=(8,4.2))
plt.scatter(lag000,vario000,s=25,marker='o',color = 'blue',label = 'Elevation')
plt.scatter(lag090,vario090,s=25,marker='o',color = 'red',label = 'East')

alcance = 200
meseta = df_filtrado["V"].var()

plt.plot([alcance,alcance],[0,meseta],color = 'red', label="Range", linestyle='dashed')

plt.plot([0,alcance*2],[meseta,meseta],color = 'orange',label = 'Statistics Variance', linestyle='dashed')



x = np.arange(0,alcance,1)
y = ((1.5*(x/alcance)) - (0.5*(x/alcance)**3))*meseta
plt.plot(x,y, color = 'red')
plt.xlabel('Lag distance (m)')
plt.ylabel('Spatial variance')
plt.ylim(0,0.5)
plt.xlim(0,400)
cbar = plt.colorbar()
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
handles, labels = plt.gca().get_legend_handles_labels()
plt.gca().legend(handles[::], labels[::])
#plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/variograma_modelo.png", dpi=300)

plt.show()

# %%
vario_kri = GSLIB.make_variogram(nug=0.0,nst=1,it1=1,cc1=meseta,azi1=0,hmaj1=200,hmin1=200) #ajuste con un unico modelo esférico
# Out:
#  make_variogram Warning: sill does not sum to 1.0, do not use in simulation

# %%
nx = 100; ny=50; xsiz=10; ysiz=10; xmn=0; ymn= 0; ndmax=20; ndmin=1;radius=200; 

ktype=1; skmean=0; nxdis=1; nydis=1; tmin=-9999; tmax=9999

kmap, vmap = geostats.kb2d(df_filtrado, "X", "Y", "V", tmin, tmax, nx, xmn, xsiz, ny, ymn, ysiz, nxdis, nydis, ndmin, ndmax, radius, ktype, skmean, vario_kri)
# Out:
#   Estimated   5000 blocks
#       average   1.9716064651814784  variance  0.18067696724712734

# %%
xmin = 0; ymin =0;                                          # grid origin

xmax = 1000; ymax = 500    # calculate the extent of model

# %%
df_kmap = pd.DataFrame(kmap) #se pasan los valores estimados al dataframe de la simulación 
df_vmap = pd.DataFrame(vmap) #se pasan los valores estimados al dataframe de la simulación 

df_vmap = df_vmap.stack().reset_index().rename(columns={"level_0": "North [Y]", "level_1": "East[X]", 0:"Var"})
df_kmap = df_kmap.stack().reset_index().rename(columns={"level_0": "North [Y]", "level_1": "East[X]", 0:"Ore grade"})

df["Var"] = df_vmap["Var"]
df["V_OK"]= df_kmap["Ore grade"]
df.head()
# Out:
#       X      Y         V    VA_RNA       Var      V_OK  Var_scaled      b_05  \
# 0   0.0  490.0  1.425655  1.020032  0.187132  1.062005    0.315466  0.099519
# 1  10.0  490.0  1.398962  1.034870  0.152383  0.996280    0.256886  0.065991
# 2  20.0  490.0  1.188708  1.055312  0.116073  0.929009    0.195676  0.038289
# 3  30.0  490.0  0.992036  1.127225  0.078479  0.867346    0.132300  0.017503
# 4  40.0  490.0  0.680945  1.198920  0.039985  0.839161    0.067407  0.004544
#
#      mlp_ok      Var1     V1_OK
# 0  1.057828  0.187132  1.062005
# 1  0.998826  0.152383  0.996280
# 2  0.933845  0.116073  0.929009
# 3  0.871895  0.078479  0.867346
# 4  0.840795  0.039985  0.839161

# %%
df["V_OK"].describe().T
# Out:
# count    5000.000000
# mean        1.971606
# std         0.425104
# min         0.000000
# 25%         1.686157
# 50%         1.946080
# 75%         2.233815
# max         3.546454
# Name: V_OK, dtype: float64

# %%
df_vmap = df_vmap.stack().reset_index().rename(columns={"level_0": "North [Y]", "level_1": "East[X]", 0:"Var"})
df.head()
# Out:
#       X      Y         V    VA_RNA       Var      V_OK
# 0   0.0  490.0  1.425655  1.020032  0.187132  1.062005
# 1  10.0  490.0  1.398962  1.034870  0.152383  0.996280
# 2  20.0  490.0  1.188708  1.055312  0.116073  0.929009
# 3  30.0  490.0  0.992036  1.127225  0.078479  0.867346
# 4  40.0  490.0  0.680945  1.198920  0.039985  0.839161

# %%
marker_size=16
plt.figure(figsize=(8.2, 4.2))
plt.scatter(df["X"], df["Y"], marker_size, df["V_OK"], cmap = cmap, marker="s")
#plt.title("Ore Grade Estimated OK")
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('North [Y]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.yticks(range(0, 501, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
#plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
#plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/sample_regular_kriging_100.png", dpi=300)

plt.show()

# %%
marker_size=16
plt.figure(figsize=(8.2, 4.2))
plt.scatter(df["X"], df["Y"], marker_size, df["Var"], cmap = cmap, marker="s")
#plt.title("Ore Grade Estimated OK")
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('North [Y]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.yticks(range(0, 501, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 0.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label("%$^2$", labelpad=+1, fontsize=12)
#plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/var_escenario2_caso1.png", dpi=300)

plt.show()

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt
x = df["V_OK"]
y = df["V"] 

# Suponiendo que x e y son arrays de NumPy o listas
# Si son series de pandas, puedes convertirlas usando: x = x.values, y = y.values

# Calcular el coeficiente de correlación lineal (R)
correlation_coefficient = np.corrcoef(x, y)[0, 1]

# Calcular el coeficiente de determinación (R^2)
r2 = r2_score(y, x)

# Calcular el error cuadrático medio (MSE)
mse = mean_squared_error(y, x)

# Calcular la raíz del error cuadrático medio (RMSE)
rmse = sqrt(mse)

# Calcular el error absoluto medio (MAE)
mae = mean_absolute_error(y, x)

print(f"Coeficiente de correlación lineal (R): {correlation_coefficient}")
print(f"Coeficiente de determinación (R^2): {r2}")
print(f"Error cuadrático medio (MSE): {mse}")
print(f"Raíz del error cuadrático medio (RMSE): {rmse}")
print(f"Error absoluto medio (MAE): {mae}")
# Out:
# Coeficiente de correlación lineal (R): 0.6414807125432525
# Coeficiente de determinación (R^2): 0.39157755581325726
# Error cuadrático medio (MSE): 0.18404778936648972
# Raíz del error cuadrático medio (RMSE): 0.42900791294157936
# Error absoluto medio (MAE): 0.3106666661303056

# %%
x = df["V"] 
y = df["V_OK"] 
slope, intercept = np.polyfit(x, y, 1)
regression_line = slope * x + intercept
r2 = r2_score(y, regression_line)
r = np.corrcoef(x, y)[0, 1]

fig = plt.figure(figsize=(5,4))
plt.scatter(x, y, color='blue', s=5, label='Data Points')
#plt.title("Validation OK", fontsize=12)
plt.plot(x, regression_line, color='red', label='Regression Line')
plt.text(0.5,3.2, 'R = {:.2f}, R\u00b2 = {:.2f}'.format(r, r2))
plt.xlabel("Ore grade")
plt.ylabel("Ore grade estimated")
plt.xlim((-0.3,3.9))
plt.ylim((-0.3,3.9))
#plt.savefig("C:/Users/nubem/Documents/NUBEMINERA_2020/GSLIB_FOLDER/data/dh_validation_ok_10percent.png", dpi=300)
# Out:
# (-0.3, 3.9)

# %% [markdown]
# # COMPARACIÓN DISTRIBUCIONES MLP VS OK

# %%
# Seleccionar las columnas relevantes para la comparación
selected_columns = ["V", "VA_RNA", "V_OK"]
df_selected = df[selected_columns]

# Etiquetas personalizadas y colores
custom_labels = {
    "VA_RNA": "NN",
    "V_OK": "OK",
    "V": "Original"
}
custom_colors = {
    "VA_RNA": "red",
    "V_OK": "blue",
    "V": "black"
}

marker_size = 2  # Cambia este valor según lo desees

# Genera el gráfico de distribución acumulada en forma de curva
plt.figure(figsize=(8.2, 4.2))
for column in df_selected.columns[1:]:
    values = np.sort(df_selected[column])
    cumulative_percentiles = np.arange(1, len(values) + 1) / len(values) * 100
    plt.plot(values, cumulative_percentiles, marker='o', markersize=marker_size, label=custom_labels[column], color=custom_colors[column])

# Agregar la variable "V" al gráfico
values_v = np.sort(df_selected["V"])
cumulative_percentiles_v = np.arange(1, len(values_v) + 1) / len(values_v) * 100
plt.plot(values_v, cumulative_percentiles_v, marker='o', markersize=marker_size, label=custom_labels["V"], color=custom_colors["V"])

plt.xlabel("Grade (%)")
plt.ylabel("Cumlative percentage (%)")
plt.legend()
#plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/distribuciones_Caso_1_escenario2.png", dpi=300)

plt.show()

# %% [markdown]
# # Modelo Hibrido MLP-OK

# %%
df.head()
# Out:
#       X      Y         V    VA_RNA       Var      V_OK
# 0   0.0  490.0  1.425655  1.020032  0.187132  1.062005
# 1  10.0  490.0  1.398962  1.034870  0.152383  0.996280
# 2  20.0  490.0  1.188708  1.055312  0.116073  0.929009
# 3  30.0  490.0  0.992036  1.127225  0.078479  0.867346
# 4  40.0  490.0  0.680945  1.198920  0.039985  0.839161

# %%
#Estandarización de la varianza:
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

df["Var_scaled"] = scaler.fit_transform(df[["Var"]])

# %%
# Definir el rango de valores de b
b_values = np.arange(0.1, 2.1, 0.1)

# Inicializar listas para almacenar los valores de R para cada escenario de b
r_values = []

# Crear una figura para el gráfico
fig = plt.figure(figsize=(6, 4.2))

# Iterar a través de los valores de b y calcular los valores de R correspondientes
for b in b_values:
    df["b_05"] = df["Var_scaled"] ** b
    df["mlp_ok"] = ((df["VA_RNA"]*df["b_05"])+((1-df["b_05"])*df["V_OK"]))
    
    x = df["V"]
    y = df["mlp_ok"]
    r = np.corrcoef(x, y)[0, 1]
    
    r_values.append(r)

# Crear el gráfico de líneas para los valores de R
plt.plot(b_values, r_values, marker='o', linestyle='-', color='blue')
plt.xlabel("Weight coefficient (b)")
plt.ylabel("Linear correlation coefficient (R)")
plt.title("b curve FCM scenario I")
plt.xticks(np.arange(0.1, 2.1, 0.2))  # Ajustar las marcas en el eje X para que se muestren cada unidad
plt.grid(False)
plt.xlim((0,2.1))
#plt.ylim((0.7, 0.76))

plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/RFBNN_python/hibrid_figures/b_curve_e1.png", dpi=300)

plt.show()

# %%
df["b_05"] = df["Var_scaled"]**2 #se crea un nuevo peso (wi) que depende de var**0.5

# %%
df["mlp_ok"] = ((df["VA_RNA"]*df["b_05"])+((1-df["b_05"])*df["V_OK"])) #Estimación Hibrida con nuevo peso b=0.5

# %%
x = df["V"] 
y = df["mlp_ok"] 
slope, intercept = np.polyfit(x, y, 1)
regression_line = slope * x + intercept
r2 = r2_score(y, regression_line)
r = np.corrcoef(x, y)[0, 1]

fig = plt.figure(figsize=(5,4))
plt.scatter(x, y, color='blue', s=5, label='Data Points')
#plt.title("Validation OK", fontsize=12)
plt.plot(x, regression_line, color='red', label='Regression Line')
plt.text(0.5,3.2, 'R = {:.2f}, R\u00b2 = {:.2f}'.format(r, r2))
plt.xlabel("Ore grade")
plt.ylabel("Ore grade estimated")
plt.xlim((-0.3,3.9))
plt.ylim((-0.3,3.9))
#plt.savefig("C:/Users/nubem/Documents/NUBEMINERA_2020/GSLIB_FOLDER/data/dh_validation_ok_10percent.png", dpi=300)
# Out:
# (-0.3, 3.9)

# %%
marker_size=15
fig = plt.figure(figsize=(16,4))
plt.subplot(121)
plt.scatter(df["X"], df["Y"], marker_size, df["b_05"], cmap = plt.cm.jet, marker="s")
#plt.title("SGSIM+Affine Correction", fontsize=20)
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 1)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
plt.subplot(122)
plt.scatter(df["X"], df["Y"], marker_size, df["mlp_ok"], cmap=plt.cm.jet, marker="s")
#plt.title("Ore Grade Estimated OK")
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('Measurement', labelpad=+1, fontsize=12)
#plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/RFBNN_python/hibrid_figures/kriging.png", dpi=300)

plt.show()

# %%
marker_size=16
plt.figure(figsize=(8.2, 4.2))
plt.scatter(df["X"], df["Y"], marker_size, df["mlp_ok"], cmap=plt.cm.jet, marker="s")
#plt.title("Ore Grade Estimated OK")
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('North [Y]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.yticks(range(0, 501, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/combinado_Flexible.png", dpi=300)

plt.show()

# %%
import numpy as np
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt
x = df["mlp_ok"]
y = df["V"] 

# Suponiendo que x e y son arrays de NumPy o listas
# Si son series de pandas, puedes convertirlas usando: x = x.values, y = y.values

# Calcular el coeficiente de correlación lineal (R)
correlation_coefficient = np.corrcoef(x, y)[0, 1]

# Calcular el coeficiente de determinación (R^2)
r2 = r2_score(y, x)

# Calcular el error cuadrático medio (MSE)
mse = mean_squared_error(y, x)

# Calcular la raíz del error cuadrático medio (RMSE)
rmse = sqrt(mse)

# Calcular el error absoluto medio (MAE)
mae = mean_absolute_error(y, x)

print(f"Coeficiente de correlación lineal (R): {correlation_coefficient}")
print(f"Coeficiente de determinación (R^2): {r2}")
print(f"Error cuadrático medio (MSE): {mse}")
print(f"Raíz del error cuadrático medio (RMSE): {rmse}")
print(f"Error absoluto medio (MAE): {mae}")
# Out:
# Coeficiente de correlación lineal (R): 0.7557298371147975
# Coeficiente de determinación (R^2): 0.5700374107226127
# Error cuadrático medio (MSE): 0.1300636832564097
# Raíz del error cuadrático medio (RMSE): 0.3606434295206412
# Error absoluto medio (MAE): 0.26722177506771

# %%
df.to_csv("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/result_ok_mlp_case1_ESCENARIO_B.csv")

# %% [markdown]
# # MODELO RIGIDO:

# %%
df.head()
# Out:
#       X      Y         V  GEO    VA_RNA       Var      V_OK  Var_scaled  \
# 0   0.0  490.0  1.425655    0  1.439603  0.187132  1.062005    0.315466
# 1  10.0  490.0  1.398962    0  1.422443  0.152383  0.996280    0.256886
# 2  20.0  490.0  1.188708    0  1.405215  0.116073  0.929009    0.195676
# 3  30.0  490.0  0.992036    0  1.392186  0.078479  0.867346    0.132300
# 4  40.0  490.0  0.680945    0  1.381803  0.039985  0.839161    0.067407
#
#        b_05    mlp_ok
# 0  0.099519  1.099583
# 1  0.065991  1.024402
# 2  0.038289  0.947243
# 3  0.017503  0.876532
# 4  0.004544  0.841626

# %%
columnas = ["X","Y", "V", "VA_RNA", "Var", "V_OK"]
df_rigido = df[columnas]
df_rigido.head()
# Out:
#       X      Y         V    VA_RNA       Var      V_OK
# 0   0.0  490.0  1.425655  1.439603  0.187132  1.062005
# 1  10.0  490.0  1.398962  1.422443  0.152383  0.996280
# 2  20.0  490.0  1.188708  1.405215  0.116073  0.929009
# 3  30.0  490.0  0.992036  1.392186  0.078479  0.867346
# 4  40.0  490.0  0.680945  1.381803  0.039985  0.839161

# %%
# Crear la nueva columna 'rigid' con valores basados en la condición
df_rigido['rigid'] = df_rigido.apply(lambda row: row['VA_RNA'] if row['Var'] > 0.25 else row['V_OK'], axis=1)
df_rigido.head()
# Out:
# C:\TEMP\ipykernel_22568\3447138609.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rigido['rigid'] = df_rigido.apply(lambda row: row['VA_RNA'] if row['Var'] > 0.25 else row['V_OK'], axis=1)
#       X      Y         V    VA_RNA       Var      V_OK     rigid
# 0   0.0  490.0  1.425655  1.439603  0.187132  1.062005  1.062005
# 1  10.0  490.0  1.398962  1.422443  0.152383  0.996280  0.996280
# 2  20.0  490.0  1.188708  1.405215  0.116073  0.929009  0.929009
# 3  30.0  490.0  0.992036  1.392186  0.078479  0.867346  0.867346
# 4  40.0  490.0  0.680945  1.381803  0.039985  0.839161  0.839161

# %%
marker_size=15
fig = plt.figure(figsize=(8,4.2))

plt.scatter(df_rigido["X"], df_rigido["Y"], marker_size, df_rigido["Var"], cmap=plt.cm.jet, marker="s")
#plt.title("Ore Grade Estimated OK")
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
#plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('Measurement', labelpad=+1, fontsize=12)
#plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/RFBNN_python/hibrid_figures/kriging.png", dpi=300)

plt.show()

# %%
marker_size=15
fig = plt.figure(figsize=(8,4.2))

plt.scatter(df_rigido["X"], df_rigido["Y"], marker_size, df_rigido["rigid"], cmap=plt.cm.jet, marker="s")
#plt.title("Ore Grade Estimated OK")
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('Measurement', labelpad=+1, fontsize=12)
plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/combinado_rigido.png", dpi=300)

plt.show()

# %%
x = df_rigido["rigid"]
y = df_rigido["V"]

# Suponiendo que x e y son arrays de NumPy o listas
# Si son series de pandas, puedes convertirlas usando: x = x.values, y = y.values

# Calcular el coeficiente de correlación lineal (R)
correlation_coefficient = np.corrcoef(x, y)[0, 1]

# Calcular el coeficiente de determinación (R^2)
r2 = r2_score(y, x)

# Calcular el error cuadrático medio (MSE)
mse = mean_squared_error(y, x)

# Calcular la raíz del error cuadrático medio (RMSE)
rmse = sqrt(mse)

# Calcular el error absoluto medio (MAE)
mae = mean_absolute_error(y, x)

print(f"Coeficiente de correlación lineal (R): {correlation_coefficient}")
print(f"Coeficiente de determinación (R^2): {r2}")
print(f"Error cuadrático medio (MSE): {mse}")
print(f"Raíz del error cuadrático medio (RMSE): {rmse}")
print(f"Error absoluto medio (MAE): {mae}")
# Out:
# Coeficiente de correlación lineal (R): 0.7380132930631992
# Coeficiente de determinación (R^2): 0.5442795731605949
# Error cuadrático medio (MSE): 0.13785542911892007
# Raíz del error cuadrático medio (RMSE): 0.3712888755658053
# Error absoluto medio (MAE): 0.27437649695623334
