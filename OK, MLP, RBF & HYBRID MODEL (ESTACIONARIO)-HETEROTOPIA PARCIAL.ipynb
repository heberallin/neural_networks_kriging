# %%
import geostatspy.GSLIB as GSLIB                          # Utilidades GSLIB y funciones envueltas
import geostatspy.geostats as geostats                    # GSLIB convertido a Python
import os                                                 # Para configurar el directorio de trabajo
import numpy as np                                        # Biblioteca de funciones matemáticas
import pandas as pd                                       # Biblioteca para manipulación de marcos de datos
import matplotlib.pyplot as plt                           # Biblioteca para salida gráfica
import scipy.stats                                        # Biblioteca de resumenes estadísticos y matemáticos
import random as rand
from sklearn.metrics import r2_score
import geostatspy.geostats as geostats                    # GSLIB convertido a Python
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras import layers
from keras.optimizers import RMSprop 
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import seaborn as sns
plt.rcParams.update(plt.rcParamsDefault)
import pygeostat as gs
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
import random
from RBFN import *
plt.rcParams.update(plt.rcParamsDefault)

os.chdir("C:/Users/nubem/Documents/NUBEMINERA_2020/GSLIB_FOLDER") # ruta de ejecutables de GSLIB

# %%
nx = 100; ny = 50; cell_size=10                             # grid number of cells and cell size
xmin = 0; ymin =0;                                          # grid origin
xmax = 1000; ymax = 500    # calculate the extent of model
seed = 172763650
vmin = 0; vmax = 1; cmap = plt.cm.jet                     # color min and max and using the plasma color map
va_mean = 2; va_stdev = 0.55; va_cmin = 0; va_cmax = 4
var = GSLIB.make_variogram(nug=0.0,nst=1,it1=1,cc1=1.0,azi1=0,hmaj1=250,hmin1=250)
V = GSLIB.sgsim_uncond(1,nx,ny,cell_size,seed,var,"u")
V = GSLIB.affine(V,va_mean,va_stdev)
df_zko = pd.DataFrame(V)
df11 = df_zko.stack().reset_index().rename(columns={"level_0": "Elevation[Z]", "level_1": "Este[X]", 0:"V"})
x = df11["Elevation[Z]"].iloc[::-1].reset_index()
df11["Elevation[Z]"] = x["Elevation[Z]"]
##############################################################################################################
grid_x = np.linspace(0,500, num=50, endpoint=False) #Coord. de origen x, coord. de termino x, nª de celdas x.
grid_y = np.linspace(0,1000, num=100, endpoint=False) #Coord. de origen y, coord. de termino y, nª de celdas y.
gy = np.array(grid_y) #conversión a un array de numpy 
gx = np.array(grid_x) #conversión a un array de numpy 
yg, xg = np.meshgrid(grid_x, grid_y, indexing='ij') #Creación de la grilla (intersecciones en yg; xg)
x_g = xg.ravel() #aplanamiento de xg
y_g = yg.ravel() #aplanamiento de yg
d = {'X': x_g, 'Y': y_g} #Columnas con coordenadas X e Y.
df = pd.DataFrame(data=d) #Creación del dataframe 
h = df["Y"].iloc[::-1].reset_index()
df["Y"] = h["Y"]
df["V"] = df11["V"] #Traspaso de la columna VA al nuevo DataFrame.
df.to_csv("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Hybrid_model_test_2023/data_test_2.csv")
#valores_x = [50, 350,650,8950]
valores_x = [50,250,350,450,550,650,750,950]
df_filtrado = df[df['X'].isin(valores_x)].copy()

for x in [950]:
    df_filtrado = df_filtrado.loc[~((df_filtrado['X'] == x) & ((df_filtrado['Y'] <= 300)))]
    
for x in [50]:
    df_filtrado = df_filtrado.loc[~((df_filtrado['X'] == x) & ((df_filtrado['Y'] <= 300)))]

df_filtrado.to_csv("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Hybrid_model_test_2023/sample_dh_test2.csv")

# %%
df.head()
# Out:
#       X      Y         V
# 0   0.0  490.0  1.425655
# 1  10.0  490.0  1.398962
# 2  20.0  490.0  1.188708
# 3  30.0  490.0  0.992036
# 4  40.0  490.0  0.680945

# %%
numero_muestra = 200  # Número de valores en la muestra aleatoria

indices_aleatorios = random.sample(range(len(df)), numero_muestra)

df_muestra = df.loc[indices_aleatorios].reset_index(drop=True)

# Concatena df_muestra y df_filtrado
df_concatenado = pd.concat([df_muestra, df_filtrado], ignore_index=True)

# Ahora, df_concatenado contiene la unión de los DataFrames df_muestra y df_filtrado
df_concatenado.head()
# Out:
#        X      Y         V
# 0   50.0  250.0  1.770638
# 1  870.0   20.0  2.430765
# 2  260.0  350.0  2.494152
# 3  630.0   80.0  2.668357
# 4   90.0  100.0  1.844011

# %%
intensidad_ruido = 1.5  # Puedes ajustar este valor según tus necesidades

df_concatenado['V'] = df_concatenado['V']*8 + np.random.normal(0, intensidad_ruido, len(df_concatenado))

df_concatenado["V"].head()
# Out:
# 0    17.504672
# 1    17.308746
# 2    20.984799
# 3    19.202675
# 4    14.120362
# Name: V, dtype: float64

# %%
marker_size=16
plt.figure(figsize=(8.2, 4.2))
marker_size=15
plt.scatter(df_filtrado["X"], df_filtrado["Y"], marker_size, df_filtrado["V"], cmap = cmap, marker="s")
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.yticks(range(0, 501, 100), fontsize=12)
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.grid(False)
plt.title("I.A")
cbar = plt.colorbar()
plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/muestra_estandar_v.png", dpi=300)
plt.plot()
# Out:
# []

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Suponiendo que df_filtrado y df_concatenado ya están definidos

marker_size=16
plt.figure(figsize=(8.2, 4.2))
plt.scatter(df_filtrado['X'], df_filtrado['Y'], c=df_filtrado['V'], cmap='jet', marker="s")

# Crear un diagrama de dispersión para df_concatenado
plt.scatter(df_concatenado['X'], df_concatenado['Y'], c=df_concatenado['V'], cmap='jet', marker='x', label='Additional sample')

plt.xticks(range(0, 1001, 100), fontsize=12)
plt.yticks(range(0, 501, 100), fontsize=12)
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.title("I.C")
plt.legend()
cbar = plt.colorbar()
plt.clim(0, 30)

cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/muestreo_hererotopico_parcial.png", dpi=300)

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

coincidencias = df_filtrado.merge(df_concatenado, on=['X', 'Y'], suffixes=('_filtrado', '_concatenado'), how='inner')
plt.figure(figsize=(8.2, 4.2))
# Crear un gráfico de dispersión con línea de regresión para comparar "V_filtrado" y "V_concatenado"
sns.lmplot(x='V_filtrado', y='V_concatenado', data=coincidencias, scatter_kws={'alpha': 0.5})

# Agregar etiquetas
plt.xlabel('Z1 grade (%)')
plt.ylabel('Z2 grade (%)')

# Calcular el coeficiente de correlación lineal
coeficiente_correlacion = coincidencias['V_filtrado'].corr(coincidencias['V_concatenado'])
print(f'Coeficiente de correlación lineal: {coeficiente_correlacion:.2f}')

plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/regresion.png", dpi=300)
plt.show()
# Out:
# Coeficiente de correlación lineal: 0.95

# %%
df_concatenado = df_concatenado.drop_duplicates(subset=['X', 'Y'], keep='first')
df_concatenado.describe().T
# Out:
#    count        mean         std        min         25%         50%  \
# X  521.0  492.111324  251.519526  10.000000  280.000000  450.000000
# Y  521.0  252.149712  146.325456   0.000000  120.000000  250.000000
# V  521.0   16.192486    4.639935   2.459486   13.267197   16.454879
#
#           75%         max
# X  650.000000  990.000000
# Y  380.000000  490.000000
# V   19.388835   29.779142

# %%
lag000, vario000, npp000 = GSLIB.gamv_2d(df_concatenado,'X','Y','V',20,25,0,12.5,25)
lag090, vario090, npp090 = GSLIB.gamv_2d(df_concatenado,'X','Y','V',20,25,90,12.5,25)

fig = plt.figure(figsize=(8,4.2))
plt.scatter(lag000,vario000,s=25,marker='o',color = 'blue',label = 'Elevation')
plt.scatter(lag090,vario090,s=25,marker='o',color = 'red',label = 'East')

alcance = 200
meseta1 = df_concatenado["V"].var()

plt.plot([alcance,alcance],[0,meseta1],color = 'red', label="Range", linestyle='dashed')

plt.plot([0,alcance*2],[meseta1,meseta1],color = 'orange',label = 'Statistics Variance', linestyle='dashed')



x = np.arange(0,alcance,1)
y = ((1.5*(x/alcance)) - (0.5*(x/alcance)**3))*meseta1
plt.plot(x,y, color = 'red')
plt.xlabel('Lag distance (m)')
plt.ylabel('Spatial variance')
#plt.ylim(0,0.5)
#plt.xlim(0,400)
cbar = plt.colorbar()
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
handles, labels = plt.gca().get_legend_handles_labels()
plt.gca().legend(handles[::], labels[::])
#plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/variograma_modelo.png", dpi=300)

plt.show()

# %%
vario_kri1 = GSLIB.make_variogram(nug=0.0,nst=1,it1=1,cc1=meseta1,azi1=0,hmaj1=200,hmin1=200) #ajuste con un unico modelo esférico
# Out:
#  make_variogram Warning: sill does not sum to 1.0, do not use in simulation

# %%
nx = 100; ny=50; xsiz=10; ysiz=10; xmn=0; ymn= 0; ndmax=20; ndmin=4;radius=200; 

ktype=1; skmean=0; nxdis=1; nydis=1; tmin=-9999; tmax=9999

kmap1, vmap1 = geostats.kb2d(df_concatenado, "X", "Y", "V", tmin, tmax, nx, xmn, xsiz, ny, ymn, ysiz, nxdis, nydis, ndmin, ndmax, radius, ktype, skmean, vario_kri1)
# Out:
#   Estimated   5000 blocks
#       average   15.946336841151075  variance  16.568104996683246

# %%
xmin = 0; ymin =0;                                          # grid origin

xmax = 1000; ymax = 500    # calculate the extent of model

# %%
df_kmap1 = pd.DataFrame(kmap1) #se pasan los valores estimados al dataframe de la simulación 
df_vmap1 = pd.DataFrame(vmap1) #se pasan los valores estimados al dataframe de la simulación 

df_vmap1 = df_vmap1.stack().reset_index().rename(columns={"level_0": "North [Y]", "level_1": "East[X]", 0:"Var"})
df_kmap1 = df_kmap1.stack().reset_index().rename(columns={"level_0": "North [Y]", "level_1": "East[X]", 0:"Ore grade"})

df["Var"] = df_vmap1["Var"]
df["V1_OK"]= df_kmap1["Ore grade"]
df.head()
# Out:
#       X      Y         V        Var     V1_OK
# 0   0.0  490.0  1.425655  13.297775  8.497820
# 1  10.0  490.0  1.398962  10.830881  7.567427
# 2  20.0  490.0  1.188708   8.236732  6.920906
# 3  30.0  490.0  0.992036   5.574541  6.337004
# 4  40.0  490.0  0.680945   2.852435  6.025129

# %%
marker_size=16
plt.figure(figsize=(8.2, 4.2))
marker_size=15
plt.scatter(df["X"], df["Y"], marker_size, df["V1_OK"], cmap = cmap, marker="s")
#plt.title("Hybrid Model (Kriging and Neural Network)")
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('North [Y]', fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
#plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
#plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/sample_regular_mlp_100.png", dpi=300)
plt.plot()
# Out:
# []

# %%
fig = plt.figure(figsize=(16,4))
plt.subplot(121)
plt.scatter(df["X"], df["Y"], marker_size, df["V"], cmap = plt.cm.jet, marker="s")
#plt.title("SGSIM+Affine Correction", fontsize=20)
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
plt.subplot(122)
plt.scatter(df_filtrado["X"], df_filtrado["Y"], marker_size,df_filtrado["V"], cmap = cmap, marker="s")
#plt.title("Drillholes spacing 150 m", fontsize=20)
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Figuras paper 1/figure_2.png", dpi=300)
plt.show()

# %%
valores_x = [50,250,350,450,550,650,750,950]
df_filtradox = df[df['X'].isin(valores_x)].copy()

for x in [950]:
    df_filtradox = df_filtradox.loc[~((df_filtradox['X'] == x) & ((df_filtradox['Y'] <= 300)))]
    
for x in [50]:
    df_filtradox = df_filtradox.loc[~((df_filtradox['X'] == x) & ((df_filtradox['Y'] <= 300)))]

df_filtradox.describe().T
# Out:
#        count          mean           std           min           25%  \
# X      338.0  5.000000e+02  2.209032e+02  5.000000e+01  3.500000e+02
# Y      338.0  2.624260e+02  1.458812e+02  0.000000e+00  1.400000e+02
# V      338.0  2.043045e+00  5.446064e-01  3.286406e-01  1.697173e+00
# Var    338.0  1.039003e-14  8.462973e-14 -2.498690e-13 -5.435769e-14
# V1_OK  338.0  1.627667e+01  4.585832e+00  2.459486e+00  1.323094e+01
#
#                 50%           75%           max
# X      5.000000e+02  6.500000e+02  9.500000e+02
# Y      2.800000e+02  3.900000e+02  4.900000e+02
# V      2.069206e+00  2.367995e+00  3.546454e+00
# Var    1.447666e-14  7.131749e-14  2.501972e-13
# V1_OK  1.653814e+01  1.941390e+01  2.977914e+01

# %%
df["GEO"] = df["V1_OK"]

df_filtrado['GEO'] = df_filtradox["V1_OK"]

# %%
fig = plt.figure(figsize=(16,4))
plt.subplot(121)
plt.scatter(df["X"], df["Y"], marker_size, df["GEO"], cmap = plt.cm.jet, marker="s")
#plt.title("SGSIM+Affine Correction", fontsize=20)
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
#plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
plt.subplot(122)
plt.scatter(df_filtrado["X"], df_filtrado["Y"], marker_size,df_filtrado["GEO"], cmap = cmap, marker="s")
#plt.title("Drillholes spacing 150 m", fontsize=20)
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
#plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
#plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Figuras paper 1/figure_2.png", dpi=300)
plt.show()

# %%
marker_size=16
plt.figure(figsize=(8.2, 4.2))
plt.scatter(df_filtrado["X"], df_filtrado["Y"], marker_size,df_filtrado["GEO"], cmap = cmap, marker="s")
#plt.title("Drillholes spacing 150 m", fontsize=20)
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.yticks(range(0, 501, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 27)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/segunda_variable.png", dpi=300)
plt.plot()
# Out:
# []

# %% [markdown]
# **B.	Muestreo irregular donde se conoce la ley mineral y un control geológico**

# %%
df_filtrado.describe().T
# Out:
#      count        mean         std        min         25%         50%  \
# X    338.0  500.000000  220.903191  50.000000  350.000000  500.000000
# Y    338.0  262.426036  145.881244   0.000000  140.000000  280.000000
# V    338.0    2.043045    0.544606   0.328641    1.697173    2.069206
# GEO  338.0   16.276671    4.585832   2.459486   13.230938   16.538140
#
#             75%         max
# X    650.000000  950.000000
# Y    390.000000  490.000000
# V      2.367995    3.546454
# GEO   19.413898   29.779142

# %% [markdown]
# # Modelo MLP:

# %%
X = df_filtrado.drop(["V"],axis=1) 
y = df_filtrado["V"]
X.head()
# Out:
#         X      Y        GEO
# 5    50.0  490.0   6.301126
# 25  250.0  490.0  12.681559
# 35  350.0  490.0  15.975062
# 45  450.0  490.0   4.371374
# 55  550.0  490.0  16.933964

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.10,random_state=17276)

# %%
X_train = pd.DataFrame(StandardScaler().fit_transform(X_train))
X_test = pd.DataFrame(StandardScaler().fit_transform(X_test))
X_train.rename(columns={0:"X", 1:"Y", 2: "GEO"}, inplace=True)
X_test.rename(columns={0:"X", 1:"Y", 2: "GEO"}, inplace=True)

# %%
network = models.Sequential()
network.add(layers.Dense(64, activation='relu', input_shape=X_train.shape[1:]))
network.add(layers.Dense(64, activation='relu'))
network.add(layers.Dense(64, activation='relu'))
network.add(layers.Dense(64, activation='relu'))
network.add(layers.Dense(1)) 
network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                256
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 12801 (50.00 KB)
# Trainable params: 12801 (50.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
network.compile(
   loss = 'mean_squared_error', 
   optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
)

# %%
history = network.fit(X_train, y_train, epochs=1000, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/1000
# 10/10 [==============================] - 4s 87ms/step - loss: 2.0316 - val_loss: 0.7282
# Epoch 2/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5472 - val_loss: 0.2622
# Epoch 3/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.1785 - val_loss: 0.2440
# Epoch 4/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.1310 - val_loss: 0.1223
# Epoch 5/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0745 - val_loss: 0.0921
# Epoch 6/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0602 - val_loss: 0.0826
# Epoch 7/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0456 - val_loss: 0.0766
# Epoch 8/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0381 - val_loss: 0.0617
# Epoch 9/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0410 - val_loss: 0.0580
# Epoch 10/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0315 - val_loss: 0.0638
# Epoch 11/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0301 - val_loss: 0.0550
# Epoch 12/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0307 - val_loss: 0.0525
# Epoch 13/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0284 - val_loss: 0.0545
# Epoch 14/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0289 - val_loss: 0.0534
# Epoch 15/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0296 - val_loss: 0.0628
# Epoch 16/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0310 - val_loss: 0.0478
# Epoch 17/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0280 - val_loss: 0.0504
# Epoch 18/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0296 - val_loss: 0.0514
# Epoch 19/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0310 - val_loss: 0.0574
# Epoch 20/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0287 - val_loss: 0.0483
# Epoch 21/1000
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0258 - val_loss: 0.0514
# Epoch 22/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0246 - val_loss: 0.0458
# Epoch 23/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0252 - val_loss: 0.0551
# Epoch 24/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0272 - val_loss: 0.0452
# Epoch 25/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0254 - val_loss: 0.0385
# Epoch 26/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0257 - val_loss: 0.0491
# Epoch 27/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0280 - val_loss: 0.0527
# Epoch 28/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0363 - val_loss: 0.0590
# Epoch 29/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0347 - val_loss: 0.0419
# Epoch 30/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0288 - val_loss: 0.0525
# Epoch 31/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0258 - val_loss: 0.0418
# Epoch 32/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0276 - val_loss: 0.0545
# Epoch 33/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0231 - val_loss: 0.0424
# Epoch 34/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0245 - val_loss: 0.0485
# Epoch 35/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0242 - val_loss: 0.0438
# Epoch 36/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0223 - val_loss: 0.0491
# Epoch 37/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0244 - val_loss: 0.0512
# Epoch 38/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0225 - val_loss: 0.0453
# Epoch 39/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0242 - val_loss: 0.0433
# Epoch 40/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0259 - val_loss: 0.0448
# Epoch 41/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0271 - val_loss: 0.0613
# Epoch 42/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0224 - val_loss: 0.0472
# Epoch 43/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0222 - val_loss: 0.0591
# Epoch 44/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0255 - val_loss: 0.0484
# Epoch 45/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0222 - val_loss: 0.0607
# Epoch 46/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0232 - val_loss: 0.0482
# Epoch 47/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0217 - val_loss: 0.0501
# Epoch 48/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0225 - val_loss: 0.0494
# Epoch 49/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0199 - val_loss: 0.0425
# Epoch 50/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0194 - val_loss: 0.0566
# Epoch 51/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0216 - val_loss: 0.0496
# Epoch 52/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0218 - val_loss: 0.0567
# Epoch 53/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0233 - val_loss: 0.0513
# Epoch 54/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0212 - val_loss: 0.0567
# Epoch 55/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0307 - val_loss: 0.0454
# Epoch 56/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0206 - val_loss: 0.0416
# Epoch 57/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0201 - val_loss: 0.0514
# Epoch 58/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0186 - val_loss: 0.0598
# Epoch 59/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0193 - val_loss: 0.0380
# Epoch 60/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0191 - val_loss: 0.0557
# Epoch 61/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0186 - val_loss: 0.0499
# Epoch 62/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0188 - val_loss: 0.0499
# Epoch 63/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0192 - val_loss: 0.0766
# Epoch 64/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0263 - val_loss: 0.0696
# Epoch 65/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0358 - val_loss: 0.0770
# Epoch 66/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0305 - val_loss: 0.0844
# Epoch 67/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0393 - val_loss: 0.0506
# Epoch 68/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0320 - val_loss: 0.0737
# Epoch 69/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0243 - val_loss: 0.0515
# Epoch 70/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0269 - val_loss: 0.0609
# Epoch 71/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0226 - val_loss: 0.0543
# Epoch 72/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0225 - val_loss: 0.0501
# Epoch 73/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0206 - val_loss: 0.0542
# Epoch 74/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0192 - val_loss: 0.0495
# Epoch 75/1000
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0219 - val_loss: 0.0613
# Epoch 76/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0212 - val_loss: 0.0604
# Epoch 77/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0226 - val_loss: 0.0490
# Epoch 78/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0206 - val_loss: 0.0573
# Epoch 79/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0194 - val_loss: 0.0519
# Epoch 80/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0173 - val_loss: 0.0540
# Epoch 81/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0189 - val_loss: 0.0530
# Epoch 82/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0182 - val_loss: 0.0514
# Epoch 83/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0175 - val_loss: 0.0605
# Epoch 84/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0189 - val_loss: 0.0644
# Epoch 85/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0203 - val_loss: 0.0398
# Epoch 86/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0195 - val_loss: 0.0662
# Epoch 87/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0210 - val_loss: 0.0568
# Epoch 88/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0297 - val_loss: 0.0654
# Epoch 89/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0238 - val_loss: 0.0612
# Epoch 90/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0218 - val_loss: 0.0639
# Epoch 91/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0208 - val_loss: 0.0476
# Epoch 92/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0181 - val_loss: 0.0659
# Epoch 93/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0218 - val_loss: 0.0506
# Epoch 94/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0176 - val_loss: 0.0597
# Epoch 95/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0172 - val_loss: 0.0582
# Epoch 96/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0226 - val_loss: 0.0563
# Epoch 97/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0186 - val_loss: 0.0648
# Epoch 98/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0193 - val_loss: 0.0446
# Epoch 99/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0247 - val_loss: 0.0703
# Epoch 100/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0224 - val_loss: 0.0616
# Epoch 101/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0300 - val_loss: 0.0912
# Epoch 102/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0299 - val_loss: 0.0653
# Epoch 103/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0284 - val_loss: 0.0526
# Epoch 104/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0221 - val_loss: 0.0820
# Epoch 105/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0205 - val_loss: 0.0531
# Epoch 106/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0175 - val_loss: 0.0625
# Epoch 107/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0205 - val_loss: 0.0514
# Epoch 108/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0174 - val_loss: 0.0580
# Epoch 109/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0166 - val_loss: 0.0600
# Epoch 110/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0158 - val_loss: 0.0546
# Epoch 111/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0178 - val_loss: 0.0638
# Epoch 112/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0187 - val_loss: 0.0479
# Epoch 113/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0191 - val_loss: 0.0812
# Epoch 114/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0218 - val_loss: 0.0619
# Epoch 115/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0191 - val_loss: 0.0653
# Epoch 116/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0178 - val_loss: 0.0619
# Epoch 117/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0209 - val_loss: 0.0490
# Epoch 118/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0200 - val_loss: 0.0575
# Epoch 119/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0185 - val_loss: 0.0548
# Epoch 120/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0185 - val_loss: 0.0471
# Epoch 121/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0155 - val_loss: 0.0575
# Epoch 122/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0150 - val_loss: 0.0426
# Epoch 123/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0154 - val_loss: 0.0632
# Epoch 124/1000
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0148 - val_loss: 0.0617
# Epoch 125/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0171 - val_loss: 0.0563
# Epoch 126/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0192 - val_loss: 0.0600
# Epoch 127/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0268 - val_loss: 0.0654
# Epoch 128/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0376 - val_loss: 0.0751
# Epoch 129/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0381 - val_loss: 0.0585
# Epoch 130/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0299 - val_loss: 0.0742
# Epoch 131/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0193 - val_loss: 0.0470
# Epoch 132/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0166 - val_loss: 0.0579
# Epoch 133/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0154 - val_loss: 0.0499
# Epoch 134/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0169 - val_loss: 0.0747
# Epoch 135/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0182 - val_loss: 0.0562
# Epoch 136/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0197 - val_loss: 0.0663
# Epoch 137/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0179 - val_loss: 0.0566
# Epoch 138/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0222 - val_loss: 0.0555
# Epoch 139/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0202 - val_loss: 0.0521
# Epoch 140/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0191 - val_loss: 0.0606
# Epoch 141/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0170 - val_loss: 0.0490
# Epoch 142/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0159 - val_loss: 0.0486
# Epoch 143/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0154 - val_loss: 0.0676
# Epoch 144/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0157 - val_loss: 0.0428
# Epoch 145/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0174 - val_loss: 0.0711
# Epoch 146/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0179 - val_loss: 0.0515
# Epoch 147/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0170 - val_loss: 0.0631
# Epoch 148/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0163 - val_loss: 0.0616
# Epoch 149/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0155 - val_loss: 0.0419
# Epoch 150/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0193 - val_loss: 0.0808
# Epoch 151/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0190 - val_loss: 0.0476
# Epoch 152/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0194 - val_loss: 0.0587
# Epoch 153/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0182 - val_loss: 0.0604
# Epoch 154/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0186 - val_loss: 0.0635
# Epoch 155/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0156 - val_loss: 0.0551
# Epoch 156/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0144 - val_loss: 0.0488
# Epoch 157/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0139 - val_loss: 0.0722
# Epoch 158/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0145 - val_loss: 0.0590
# Epoch 159/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0155 - val_loss: 0.0593
# Epoch 160/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0163 - val_loss: 0.0675
# Epoch 161/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0169 - val_loss: 0.0615
# Epoch 162/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0196 - val_loss: 0.0592
# Epoch 163/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0170 - val_loss: 0.0633
# Epoch 164/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0196 - val_loss: 0.0513
# Epoch 165/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0185 - val_loss: 0.0713
# Epoch 166/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0181 - val_loss: 0.0432
# Epoch 167/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0170 - val_loss: 0.0615
# Epoch 168/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0147 - val_loss: 0.0603
# Epoch 169/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0139 - val_loss: 0.0544
# Epoch 170/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0140 - val_loss: 0.0630
# Epoch 171/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0129 - val_loss: 0.0471
# Epoch 172/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0133 - val_loss: 0.0655
# Epoch 173/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0130 - val_loss: 0.0531
# Epoch 174/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0149 - val_loss: 0.0694
# Epoch 175/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0166 - val_loss: 0.0880
# Epoch 176/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0162 - val_loss: 0.0468
# Epoch 177/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0157 - val_loss: 0.0700
# Epoch 178/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0126 - val_loss: 0.0561
# Epoch 179/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0132 - val_loss: 0.0517
# Epoch 180/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0124 - val_loss: 0.0657
# Epoch 181/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0134 - val_loss: 0.0703
# Epoch 182/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0147 - val_loss: 0.0542
# Epoch 183/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0141 - val_loss: 0.0656
# Epoch 184/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0144 - val_loss: 0.0616
# Epoch 185/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0136 - val_loss: 0.0637
# Epoch 186/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0159 - val_loss: 0.0698
# Epoch 187/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0153 - val_loss: 0.0638
# Epoch 188/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0188 - val_loss: 0.0705
# Epoch 189/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0165 - val_loss: 0.0687
# Epoch 190/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0139 - val_loss: 0.0451
# Epoch 191/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0141 - val_loss: 0.0591
# Epoch 192/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0156 - val_loss: 0.0765
# Epoch 193/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0139 - val_loss: 0.0471
# Epoch 194/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0150 - val_loss: 0.0802
# Epoch 195/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0183 - val_loss: 0.0522
# Epoch 196/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0141 - val_loss: 0.0566
# Epoch 197/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0158 - val_loss: 0.0804
# Epoch 198/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0165 - val_loss: 0.0644
# Epoch 199/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0152 - val_loss: 0.0499
# Epoch 200/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0149 - val_loss: 0.0568
# Epoch 201/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0185 - val_loss: 0.0600
# Epoch 202/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0140 - val_loss: 0.0857
# Epoch 203/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0139 - val_loss: 0.0546
# Epoch 204/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0150 - val_loss: 0.0662
# Epoch 205/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0152 - val_loss: 0.0517
# Epoch 206/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0130 - val_loss: 0.0556
# Epoch 207/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0144 - val_loss: 0.0683
# Epoch 208/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0144 - val_loss: 0.0507
# Epoch 209/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0118 - val_loss: 0.0560
# Epoch 210/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0114 - val_loss: 0.0690
# Epoch 211/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0131 - val_loss: 0.0392
# Epoch 212/1000
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0143 - val_loss: 0.0665
# Epoch 213/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0132 - val_loss: 0.0701
# Epoch 214/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0182 - val_loss: 0.0763
# Epoch 215/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0140 - val_loss: 0.0546
# Epoch 216/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0134 - val_loss: 0.0763
# Epoch 217/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0149 - val_loss: 0.0840
# Epoch 218/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0143 - val_loss: 0.0550
# Epoch 219/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0133 - val_loss: 0.0608
# Epoch 220/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0120 - val_loss: 0.0693
# Epoch 221/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0128 - val_loss: 0.0670
# Epoch 222/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0131 - val_loss: 0.0468
# Epoch 223/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0122 - val_loss: 0.0789
# Epoch 224/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0119 - val_loss: 0.0631
# Epoch 225/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0115 - val_loss: 0.0592
# Epoch 226/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0114 - val_loss: 0.0632
# Epoch 227/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0114 - val_loss: 0.0602
# Epoch 228/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0124 - val_loss: 0.0753
# Epoch 229/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0211 - val_loss: 0.0678
# Epoch 230/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0165 - val_loss: 0.0712
# Epoch 231/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0139 - val_loss: 0.0468
# Epoch 232/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0162 - val_loss: 0.0597
# Epoch 233/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0142 - val_loss: 0.0513
# Epoch 234/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0116 - val_loss: 0.0660
# Epoch 235/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0160 - val_loss: 0.0697
# Epoch 236/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0142 - val_loss: 0.0522
# Epoch 237/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0114 - val_loss: 0.0594
# Epoch 238/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0136 - val_loss: 0.0823
# Epoch 239/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0144 - val_loss: 0.0501
# Epoch 240/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0115 - val_loss: 0.0564
# Epoch 241/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0111 - val_loss: 0.0599
# Epoch 242/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0109 - val_loss: 0.0582
# Epoch 243/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0131 - val_loss: 0.0663
# Epoch 244/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0132 - val_loss: 0.0613
# Epoch 245/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0130 - val_loss: 0.0997
# Epoch 246/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0184 - val_loss: 0.0553
# Epoch 247/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0226 - val_loss: 0.0627
# Epoch 248/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0149 - val_loss: 0.0633
# Epoch 249/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0157 - val_loss: 0.0534
# Epoch 250/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0164 - val_loss: 0.0656
# Epoch 251/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0123 - val_loss: 0.0685
# Epoch 252/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0125 - val_loss: 0.0486
# Epoch 253/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0129 - val_loss: 0.0679
# Epoch 254/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0152 - val_loss: 0.0548
# Epoch 255/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0162 - val_loss: 0.0647
# Epoch 256/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0156 - val_loss: 0.0516
# Epoch 257/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0169 - val_loss: 0.0662
# Epoch 258/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0165 - val_loss: 0.0515
# Epoch 259/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0178 - val_loss: 0.0704
# Epoch 260/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0181 - val_loss: 0.0419
# Epoch 261/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0159 - val_loss: 0.0769
# Epoch 262/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0114 - val_loss: 0.0550
# Epoch 263/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0114 - val_loss: 0.0715
# Epoch 264/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0117 - val_loss: 0.0570
# Epoch 265/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0100 - val_loss: 0.0641
# Epoch 266/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0108 - val_loss: 0.0517
# Epoch 267/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0120 - val_loss: 0.0655
# Epoch 268/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0113 - val_loss: 0.0470
# Epoch 269/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0125 - val_loss: 0.0615
# Epoch 270/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0140 - val_loss: 0.0514
# Epoch 271/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0122 - val_loss: 0.0610
# Epoch 272/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0143 - val_loss: 0.0564
# Epoch 273/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0142 - val_loss: 0.0689
# Epoch 274/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0098 - val_loss: 0.0620
# Epoch 275/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0106 - val_loss: 0.0528
# Epoch 276/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0155 - val_loss: 0.0731
# Epoch 277/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0136 - val_loss: 0.0603
# Epoch 278/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0117 - val_loss: 0.0621
# Epoch 279/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0128 - val_loss: 0.0668
# Epoch 280/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0110 - val_loss: 0.0568
# Epoch 281/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0122 - val_loss: 0.0625
# Epoch 282/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0099 - val_loss: 0.0583
# Epoch 283/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0095 - val_loss: 0.0625
# Epoch 284/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0100 - val_loss: 0.0621
# Epoch 285/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0120 - val_loss: 0.0501
# Epoch 286/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0121 - val_loss: 0.0665
# Epoch 287/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0107 - val_loss: 0.0552
# Epoch 288/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0126 - val_loss: 0.0600
# Epoch 289/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0126 - val_loss: 0.0452
# Epoch 290/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0152 - val_loss: 0.0590
# Epoch 291/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0135 - val_loss: 0.0744
# Epoch 292/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0109 - val_loss: 0.0439
# Epoch 293/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0106 - val_loss: 0.0595
# Epoch 294/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0113 - val_loss: 0.0613
# Epoch 295/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0141 - val_loss: 0.0523
# Epoch 296/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0160 - val_loss: 0.0698
# Epoch 297/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0169 - val_loss: 0.0726
# Epoch 298/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0124 - val_loss: 0.0694
# Epoch 299/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0136 - val_loss: 0.0523
# Epoch 300/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0119 - val_loss: 0.0801
# Epoch 301/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0171 - val_loss: 0.0583
# Epoch 302/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0136 - val_loss: 0.0681
# Epoch 303/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0147 - val_loss: 0.0469
# Epoch 304/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0126 - val_loss: 0.0734
# Epoch 305/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0114 - val_loss: 0.0607
# Epoch 306/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0105 - val_loss: 0.0609
# Epoch 307/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0092 - val_loss: 0.0462
# Epoch 308/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0102 - val_loss: 0.0802
# Epoch 309/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0093 - val_loss: 0.0555
# Epoch 310/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0106 - val_loss: 0.0543
# Epoch 311/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0107 - val_loss: 0.0628
# Epoch 312/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0098 - val_loss: 0.0664
# Epoch 313/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0095 - val_loss: 0.0514
# Epoch 314/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0119 - val_loss: 0.0679
# Epoch 315/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0111 - val_loss: 0.0540
# Epoch 316/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0150 - val_loss: 0.0691
# Epoch 317/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0145 - val_loss: 0.0614
# Epoch 318/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0098 - val_loss: 0.0572
# Epoch 319/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0100 - val_loss: 0.0638
# Epoch 320/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0107 - val_loss: 0.0613
# Epoch 321/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0091 - val_loss: 0.0526
# Epoch 322/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0114 - val_loss: 0.0659
# Epoch 323/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0116 - val_loss: 0.0593
# Epoch 324/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0128 - val_loss: 0.0640
# Epoch 325/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0134 - val_loss: 0.0710
# Epoch 326/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0150 - val_loss: 0.0704
# Epoch 327/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0148 - val_loss: 0.0713
# Epoch 328/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0159 - val_loss: 0.0717
# Epoch 329/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0128 - val_loss: 0.0521
# Epoch 330/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0091 - val_loss: 0.0674
# Epoch 331/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0085 - val_loss: 0.0537
# Epoch 332/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0084 - val_loss: 0.0639
# Epoch 333/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0077 - val_loss: 0.0570
# Epoch 334/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0081 - val_loss: 0.0553
# Epoch 335/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0084 - val_loss: 0.0543
# Epoch 336/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0084 - val_loss: 0.0656
# Epoch 337/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0105 - val_loss: 0.0615
# Epoch 338/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0085 - val_loss: 0.0753
# Epoch 339/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0113 - val_loss: 0.0509
# Epoch 340/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0116 - val_loss: 0.0713
# Epoch 341/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0110 - val_loss: 0.0551
# Epoch 342/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0092 - val_loss: 0.0593
# Epoch 343/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0103 - val_loss: 0.0537
# Epoch 344/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0092 - val_loss: 0.0725
# Epoch 345/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0101 - val_loss: 0.0611
# Epoch 346/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0108 - val_loss: 0.0504
# Epoch 347/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0083 - val_loss: 0.0674
# Epoch 348/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0086 - val_loss: 0.0567
# Epoch 349/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0102 - val_loss: 0.0741
# Epoch 350/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0105 - val_loss: 0.0643
# Epoch 351/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0112 - val_loss: 0.0606
# Epoch 352/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0085 - val_loss: 0.0535
# Epoch 353/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0103 - val_loss: 0.0766
# Epoch 354/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0091 - val_loss: 0.0590
# Epoch 355/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0088 - val_loss: 0.0629
# Epoch 356/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0096 - val_loss: 0.0631
# Epoch 357/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0114 - val_loss: 0.0655
# Epoch 358/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0095 - val_loss: 0.0582
# Epoch 359/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0079 - val_loss: 0.0669
# Epoch 360/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0080 - val_loss: 0.0665
# Epoch 361/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0081 - val_loss: 0.0540
# Epoch 362/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0073 - val_loss: 0.0664
# Epoch 363/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0075 - val_loss: 0.0578
# Epoch 364/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0082 - val_loss: 0.0815
# Epoch 365/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0094 - val_loss: 0.0568
# Epoch 366/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0089 - val_loss: 0.0630
# Epoch 367/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0130 - val_loss: 0.0813
# Epoch 368/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0122 - val_loss: 0.0467
# Epoch 369/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0131 - val_loss: 0.0628
# Epoch 370/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0121 - val_loss: 0.0565
# Epoch 371/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0128 - val_loss: 0.0587
# Epoch 372/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0143 - val_loss: 0.0796
# Epoch 373/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0177 - val_loss: 0.0620
# Epoch 374/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0196 - val_loss: 0.0678
# Epoch 375/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0211 - val_loss: 0.0483
# Epoch 376/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0145 - val_loss: 0.0520
# Epoch 377/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0122 - val_loss: 0.0629
# Epoch 378/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0099 - val_loss: 0.0452
# Epoch 379/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0133 - val_loss: 0.0697
# Epoch 380/1000
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0106 - val_loss: 0.0604
# Epoch 381/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0100 - val_loss: 0.0599
# Epoch 382/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0103 - val_loss: 0.0661
# Epoch 383/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0108 - val_loss: 0.0542
# Epoch 384/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0116 - val_loss: 0.0562
# Epoch 385/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0107 - val_loss: 0.0670
# Epoch 386/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0084 - val_loss: 0.0509
# Epoch 387/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0096 - val_loss: 0.0648
# Epoch 388/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0087 - val_loss: 0.0548
# Epoch 389/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0069 - val_loss: 0.0603
# Epoch 390/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0067 - val_loss: 0.0598
# Epoch 391/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0067 - val_loss: 0.0502
# Epoch 392/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0082 - val_loss: 0.0657
# Epoch 393/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0086 - val_loss: 0.0605
# Epoch 394/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0090 - val_loss: 0.0614
# Epoch 395/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0085 - val_loss: 0.0732
# Epoch 396/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0088 - val_loss: 0.0598
# Epoch 397/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0089 - val_loss: 0.0674
# Epoch 398/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0083 - val_loss: 0.0551
# Epoch 399/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0103 - val_loss: 0.0584
# Epoch 400/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0099 - val_loss: 0.0856
# Epoch 401/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0147 - val_loss: 0.0587
# Epoch 402/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0133 - val_loss: 0.0468
# Epoch 403/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0131 - val_loss: 0.0713
# Epoch 404/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0148 - val_loss: 0.0583
# Epoch 405/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0133 - val_loss: 0.0505
# Epoch 406/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0158 - val_loss: 0.0470
# Epoch 407/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0112 - val_loss: 0.0681
# Epoch 408/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0101 - val_loss: 0.0612
# Epoch 409/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0100 - val_loss: 0.0571
# Epoch 410/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0081 - val_loss: 0.0663
# Epoch 411/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0093 - val_loss: 0.0729
# Epoch 412/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0099 - val_loss: 0.0595
# Epoch 413/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0099 - val_loss: 0.0577
# Epoch 414/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0096 - val_loss: 0.0680
# Epoch 415/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0081 - val_loss: 0.0513
# Epoch 416/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0097 - val_loss: 0.0685
# Epoch 417/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0086 - val_loss: 0.0594
# Epoch 418/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0085 - val_loss: 0.0462
# Epoch 419/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0089 - val_loss: 0.0729
# Epoch 420/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0086 - val_loss: 0.0506
# Epoch 421/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0110 - val_loss: 0.0533
# Epoch 422/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0088 - val_loss: 0.0563
# Epoch 423/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0105 - val_loss: 0.0617
# Epoch 424/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0092 - val_loss: 0.0606
# Epoch 425/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0082 - val_loss: 0.0432
# Epoch 426/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0072 - val_loss: 0.0720
# Epoch 427/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0624
# Epoch 428/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0058 - val_loss: 0.0647
# Epoch 429/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0081 - val_loss: 0.0566
# Epoch 430/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0076 - val_loss: 0.0504
# Epoch 431/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0082 - val_loss: 0.0808
# Epoch 432/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0089 - val_loss: 0.0518
# Epoch 433/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0080 - val_loss: 0.0587
# Epoch 434/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0083 - val_loss: 0.0563
# Epoch 435/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0106 - val_loss: 0.0733
# Epoch 436/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0112 - val_loss: 0.0569
# Epoch 437/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0116 - val_loss: 0.0528
# Epoch 438/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0141 - val_loss: 0.0742
# Epoch 439/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0144 - val_loss: 0.0678
# Epoch 440/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0092 - val_loss: 0.0475
# Epoch 441/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0083 - val_loss: 0.0614
# Epoch 442/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0096 - val_loss: 0.0545
# Epoch 443/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0076 - val_loss: 0.0588
# Epoch 444/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0073 - val_loss: 0.0626
# Epoch 445/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0086 - val_loss: 0.0532
# Epoch 446/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0081 - val_loss: 0.0473
# Epoch 447/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0079 - val_loss: 0.0693
# Epoch 448/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0101 - val_loss: 0.0748
# Epoch 449/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0090 - val_loss: 0.0480
# Epoch 450/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0088 - val_loss: 0.0738
# Epoch 451/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0080 - val_loss: 0.0526
# Epoch 452/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0070 - val_loss: 0.0631
# Epoch 453/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0064 - val_loss: 0.0642
# Epoch 454/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0061 - val_loss: 0.0521
# Epoch 455/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0065 - val_loss: 0.0677
# Epoch 456/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0072 - val_loss: 0.0582
# Epoch 457/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0161 - val_loss: 0.0555
# Epoch 458/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0124 - val_loss: 0.0833
# Epoch 459/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0113 - val_loss: 0.0562
# Epoch 460/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0092 - val_loss: 0.0691
# Epoch 461/1000
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0097 - val_loss: 0.0603
# Epoch 462/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0087 - val_loss: 0.0550
# Epoch 463/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0099 - val_loss: 0.0596
# Epoch 464/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0095 - val_loss: 0.0587
# Epoch 465/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0076 - val_loss: 0.0716
# Epoch 466/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.0488
# Epoch 467/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0092 - val_loss: 0.0708
# ...
# Epoch 846/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0043 - val_loss: 0.0648
# Epoch 847/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 0.0725
# Epoch 848/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0598
# Epoch 849/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0057 - val_loss: 0.0589
# Epoch 850/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0050 - val_loss: 0.0658
# Epoch 851/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0042 - val_loss: 0.0625
# Epoch 852/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0043 - val_loss: 0.0747
# Epoch 853/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0053 - val_loss: 0.0602
# Epoch 854/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 0.0622
# Epoch 855/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0765
# Epoch 856/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0065 - val_loss: 0.0587
# Epoch 857/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0059 - val_loss: 0.0757
# Epoch 858/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0065 - val_loss: 0.0706
# Epoch 859/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0563
# Epoch 860/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0757
# Epoch 861/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0584
# Epoch 862/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0056 - val_loss: 0.0631
# Epoch 863/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0599
# Epoch 864/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0053 - val_loss: 0.0767
# Epoch 865/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0063 - val_loss: 0.0649
# Epoch 866/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0068 - val_loss: 0.0644
# Epoch 867/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0052 - val_loss: 0.0571
# Epoch 868/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 0.0585
# Epoch 869/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0040 - val_loss: 0.0674
# Epoch 870/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0042 - val_loss: 0.0692
# Epoch 871/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0040 - val_loss: 0.0707
# Epoch 872/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0036 - val_loss: 0.0743
# Epoch 873/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0039 - val_loss: 0.0708
# Epoch 874/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0043 - val_loss: 0.0639
# Epoch 875/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 0.0614
# Epoch 876/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0043 - val_loss: 0.0727
# Epoch 877/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0064 - val_loss: 0.0652
# Epoch 878/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0674
# Epoch 879/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0053 - val_loss: 0.0585
# Epoch 880/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 0.0650
# Epoch 881/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0698
# Epoch 882/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0085 - val_loss: 0.0725
# Epoch 883/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0087 - val_loss: 0.0596
# Epoch 884/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0066 - val_loss: 0.0768
# Epoch 885/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0061 - val_loss: 0.0484
# Epoch 886/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0058 - val_loss: 0.0656
# Epoch 887/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0071 - val_loss: 0.0702
# Epoch 888/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0084 - val_loss: 0.0640
# Epoch 889/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0072 - val_loss: 0.0611
# Epoch 890/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0081 - val_loss: 0.0479
# Epoch 891/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0077 - val_loss: 0.0597
# Epoch 892/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0082 - val_loss: 0.0668
# Epoch 893/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0074 - val_loss: 0.0602
# Epoch 894/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0076 - val_loss: 0.0661
# Epoch 895/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0083 - val_loss: 0.0689
# Epoch 896/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0061 - val_loss: 0.0645
# Epoch 897/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0064 - val_loss: 0.0614
# Epoch 898/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0039 - val_loss: 0.0583
# Epoch 899/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0041 - val_loss: 0.0693
# Epoch 900/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0038 - val_loss: 0.0634
# Epoch 901/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0053 - val_loss: 0.0602
# Epoch 902/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0046 - val_loss: 0.0810
# Epoch 903/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0528
# Epoch 904/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0068 - val_loss: 0.0712
# Epoch 905/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0068 - val_loss: 0.0578
# Epoch 906/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0056 - val_loss: 0.0516
# Epoch 907/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0676
# Epoch 908/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0063 - val_loss: 0.0569
# Epoch 909/1000
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0067 - val_loss: 0.0714
# Epoch 910/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0068 - val_loss: 0.0687
# Epoch 911/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0057 - val_loss: 0.0618
# Epoch 912/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0058 - val_loss: 0.0748
# Epoch 913/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0064 - val_loss: 0.0625
# Epoch 914/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0095 - val_loss: 0.0527
# Epoch 915/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0721
# Epoch 916/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0632
# Epoch 917/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0044 - val_loss: 0.0670
# Epoch 918/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 0.0585
# Epoch 919/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0040 - val_loss: 0.0606
# Epoch 920/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0038 - val_loss: 0.0641
# Epoch 921/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0034 - val_loss: 0.0573
# Epoch 922/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0038 - val_loss: 0.0750
# Epoch 923/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 0.0502
# Epoch 924/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0067 - val_loss: 0.0771
# Epoch 925/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0059 - val_loss: 0.0640
# Epoch 926/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0052 - val_loss: 0.0661
# Epoch 927/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0041 - val_loss: 0.0606
# Epoch 928/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0041 - val_loss: 0.0614
# Epoch 929/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0042 - val_loss: 0.0595
# Epoch 930/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0040 - val_loss: 0.0750
# Epoch 931/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0062 - val_loss: 0.0574
# Epoch 932/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0044 - val_loss: 0.0692
# Epoch 933/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0043 - val_loss: 0.0688
# Epoch 934/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0036 - val_loss: 0.0611
# Epoch 935/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0035 - val_loss: 0.0596
# Epoch 936/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0037 - val_loss: 0.0634
# Epoch 937/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0029 - val_loss: 0.0627
# Epoch 938/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0028 - val_loss: 0.0563
# Epoch 939/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0032 - val_loss: 0.0605
# Epoch 940/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0035 - val_loss: 0.0622
# Epoch 941/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0038 - val_loss: 0.0584
# Epoch 942/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0053 - val_loss: 0.0640
# Epoch 943/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0059 - val_loss: 0.0636
# Epoch 944/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0054 - val_loss: 0.0568
# Epoch 945/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0627
# Epoch 946/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0046 - val_loss: 0.0590
# Epoch 947/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0040 - val_loss: 0.0675
# Epoch 948/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0051 - val_loss: 0.0643
# Epoch 949/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0050 - val_loss: 0.0694
# Epoch 950/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0042 - val_loss: 0.0695
# Epoch 951/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0593
# Epoch 952/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0626
# Epoch 953/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 0.0552
# Epoch 954/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 0.0562
# Epoch 955/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0042 - val_loss: 0.0578
# Epoch 956/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0036 - val_loss: 0.0581
# Epoch 957/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0034 - val_loss: 0.0631
# Epoch 958/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0033 - val_loss: 0.0684
# Epoch 959/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0034 - val_loss: 0.0572
# Epoch 960/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0035 - val_loss: 0.0646
# Epoch 961/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0037 - val_loss: 0.0624
# Epoch 962/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 0.0632
# Epoch 963/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0027 - val_loss: 0.0625
# Epoch 964/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0028 - val_loss: 0.0617
# Epoch 965/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0040 - val_loss: 0.0693
# Epoch 966/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0040 - val_loss: 0.0585
# Epoch 967/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0037 - val_loss: 0.0608
# Epoch 968/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0047 - val_loss: 0.0618
# Epoch 969/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0592
# Epoch 970/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0051 - val_loss: 0.0589
# Epoch 971/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 0.0598
# Epoch 972/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 0.0647
# Epoch 973/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 0.0750
# Epoch 974/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0624
# Epoch 975/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.0590
# Epoch 976/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0058 - val_loss: 0.0683
# Epoch 977/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0076 - val_loss: 0.0804
# Epoch 978/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0056 - val_loss: 0.0644
# Epoch 979/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 0.0627
# Epoch 980/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0044 - val_loss: 0.0672
# Epoch 981/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0039 - val_loss: 0.0600
# Epoch 982/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0032 - val_loss: 0.0694
# Epoch 983/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 0.0580
# Epoch 984/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 0.0624
# Epoch 985/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0030 - val_loss: 0.0668
# Epoch 986/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0032 - val_loss: 0.0625
# Epoch 987/1000
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0034 - val_loss: 0.0631
# Epoch 988/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0030 - val_loss: 0.0590
# Epoch 989/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0035 - val_loss: 0.0692
# Epoch 990/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0039 - val_loss: 0.0589
# Epoch 991/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0044 - val_loss: 0.0638
# Epoch 992/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0048 - val_loss: 0.0553
# Epoch 993/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0750
# Epoch 994/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 0.0550
# Epoch 995/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0047 - val_loss: 0.0717
# Epoch 996/1000
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0049 - val_loss: 0.0628
# Epoch 997/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0050 - val_loss: 0.0687
# Epoch 998/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0644
# Epoch 999/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0041 - val_loss: 0.0537
# Epoch 1000/1000
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0046 - val_loss: 0.0564

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Predicciones en el conjunto de entrenamiento y prueba
y_train_pred = network.predict(X_train)
y_test_pred = network.predict(X_test)

# Métricas en el conjunto de entrenamiento
r_train = np.corrcoef(y_train, y_train_pred.squeeze())[0, 1]
r2_train = r2_score(y_train, y_train_pred)
mse_train = mean_squared_error(y_train, y_train_pred)
rmse_train = np.sqrt(mse_train)
mae_train = mean_absolute_error(y_train, y_train_pred)

# Métricas en el conjunto de prueba
r_test = np.corrcoef(y_test, y_test_pred.squeeze())[0, 1]
r2_test = r2_score(y_test, y_test_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
rmse_test = np.sqrt(mse_test)
mae_test = mean_absolute_error(y_test, y_test_pred)

# Imprimir las métricas
print("Métricas en el conjunto de entrenamiento:")
print("R:", r_train)
print("R2:", r2_train)
print("MSE:", mse_train)
print("RMSE:", rmse_train)
print("MAE:", mae_train)
print("")

print("Métricas en el conjunto de prueba:")
print("R:", r_test)
print("R2:", r2_test)
print("MSE:", mse_test)
print("RMSE:", rmse_test)
print("MAE:", mae_test)
# Out:
# 10/10 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 11ms/step
# Métricas en el conjunto de entrenamiento:
# R: 0.9932452098110294
# R2: 0.9787087048417702
# MSE: 0.005929283501609179
# RMSE: 0.07700184089753426
# MAE: 0.05607989835198056
#
# Métricas en el conjunto de prueba:
# R: 0.9420744018911205
# R2: 0.8734750760739174
# MSE: 0.056414412209558486
# RMSE: 0.23751718297748162
# MAE: 0.18520637914338514

# %%
grid_x = np.linspace(0,500, num=50, endpoint=False) #Coord. de origen x, coord. de termino x, nª de celdas x.
grid_y = np.linspace(0,1000, num=100, endpoint=False) #Coord. de origen y, coord. de termino y, nª de celdas y.

#En este caso la matriz es de 100 x 100 celdas.

gy = np.array(grid_y) #conversión a un array de numpy 
gx = np.array(grid_x) #conversión a un array de numpy 

yg, xg = np.meshgrid(grid_x, grid_y, indexing='ij') #Creación de la grilla (intersecciones en yg; xg)

x_g = xg.ravel() #aplanamiento de xg
y_g = yg.ravel() #aplanamiento de yg

d = {'Este[X]': x_g, 'Norte[Y]': y_g} #Columnas con coordenadas X e Y.
df2 = pd.DataFrame(data=d) #Creación del dataframe 

h = df2["Norte[Y]"].iloc[::-1].reset_index()

df2["Norte[Y]"] = h["Norte[Y]"]


#df5 = df_filtrado.reset_index()

df2["GEO"] = df["GEO"]

df2 = pd.DataFrame(StandardScaler().fit_transform(df2))
df2.rename(columns={0:"X", 1:"Y",2:"GEO"}, inplace=True)

df2.head()
# Out:
#           X         Y       GEO
# 0 -1.714816  1.697749 -1.829925
# 1 -1.680173  1.697749 -2.058501
# 2 -1.645531  1.697749 -2.217336
# 3 -1.610888  1.697749 -2.360787
# 4 -1.576245  1.697749 -2.437407

# %%
df2.describe().T
# Out:
#       count          mean     std       min       25%       50%       75%  \
# X    5000.0  8.526513e-18  1.0001 -1.714816 -0.857408  0.000000  0.857408
# Y    5000.0 -9.094947e-17  1.0001 -1.697749 -0.866199  0.000000  0.866199
# GEO  5000.0 -6.764367e-16  1.0001 -3.313402 -0.626811 -0.000135  0.674264
#
#           max
# X    1.714816
# Y    1.697749
# GEO  3.398395

# %%
y_pred3 = network.predict(df2) #uso del modelo para un conjunto nuevo de datos de entrada (bloques zona óxido)
df2["VA_RNA"] = y_pred3
df["VA_RNA"] = df2["VA_RNA"]
df.head()
# Out:
# 157/157 [==============================] - 1s 3ms/step
#       X      Y         V        Var     V1_OK       GEO    VA_RNA
# 0   0.0  490.0  1.425655  13.297775  8.497820  8.497820  1.092430
# 1  10.0  490.0  1.398962  10.830881  7.567427  7.567427  0.975693
# 2  20.0  490.0  1.188708   8.236732  6.920906  6.920906  0.930960
# 3  30.0  490.0  0.992036   5.574541  6.337004  6.337004  0.861693
# 4  40.0  490.0  0.680945   2.852435  6.025129  6.025129  0.796195

# %%
df.describe().T
# Out:
#          count        mean         std           min         25%         50%  \
# X       5000.0  495.000000  288.689571  0.000000e+00  247.500000  495.000000
# Y       5000.0  245.000000  144.323130  0.000000e+00  120.000000  245.000000
# V       5000.0    2.000000    0.550055  9.669300e-02    1.642968    2.000339
# Var     5000.0    3.652215    2.010479 -2.498690e-13    2.350132    3.615373
# V1_OK   5000.0   15.946337    4.070801  2.459486e+00   13.394968   15.945788
# GEO     5000.0   15.946337    4.070801  2.459486e+00   13.394968   15.945788
# VA_RNA  5000.0    2.004151    0.463667  5.337577e-01    1.701616    2.012445
#
#                75%         max
# X       742.500000  990.000000
# Y       370.000000  490.000000
# V         2.364052    3.931615
# Var       4.981559   13.297775
# V1_OK    18.690855   29.779142
# GEO      18.690855   29.779142
# VA_RNA    2.279066    3.710544

# %%
import numpy as np
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Supongamos que tienes dos arrays con valores reales (y_true) y predicciones (y_pred)
y_true = df["V"] 
y_pred = df["VA_RNA"] 

# Calcular las métricas
r = np.corrcoef(y_true, y_pred)[0, 1]
r2 = r2_score(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mse = mean_squared_error(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)

# Imprimir los resultados
print(f"Coeficiente de correlación (R): {r:.4f}")
print(f"Coeficiente de determinación (R²): {r2:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MSE: {mse:.4f}")
print(f"MAE: {mae:.4f}")
# Out:
# Coeficiente de correlación (R): 0.7794
# Coeficiente de determinación (R²): 0.6033
# RMSE: 0.3464
# MSE: 0.1200
# MAE: 0.2677

# %%
marker_size=16
plt.figure(figsize=(8.2, 4.2))
marker_size=15
plt.scatter(df["X"], df["Y"], marker_size, df2["VA_RNA"], cmap = cmap, marker="s")
#plt.title("Hybrid Model (Kriging and Neural Network)")
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('North [Y]', fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
#plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/sample_regular_mlp_100.png", dpi=300)
plt.plot()
# Out:
# []

# %%
marker_size=16
fig = plt.figure(figsize=(16,4))
plt.subplot(121)
plt.scatter(df["X"], df["Y"], marker_size, df["V"], cmap = plt.cm.jet, marker="s")
#plt.title("SGSIM+Affine Correction", fontsize=20)
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
plt.subplot(122)
plt.scatter(df["X"], df["Y"], marker_size, df2["VA_RNA"], cmap = cmap, marker="s")
#plt.title("Hybrid Model (Kriging and Neural Network)")
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('North [Y]', fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
#plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Figuras paper 1/figure_2.png", dpi=300)
plt.show()

# %% [markdown]
# # MODELO OK:

# %%
lag000, vario000, npp000 = GSLIB.gamv_2d(df_filtrado,'X','Y','V',20,25,0,12.5,25)
lag090, vario090, npp090 = GSLIB.gamv_2d(df_filtrado,'X','Y','V',20,25,90,12.5,25)

# %%
df_filtrado["V"].var()
# Out:
# 0.2965961361135752

# %%
fig = plt.figure(figsize=(8,4.2))
plt.scatter(lag000,vario000,s=25,marker='o',color = 'blue',label = 'Elevation')
plt.scatter(lag090,vario090,s=25,marker='o',color = 'red',label = 'East')

alcance = 200
meseta = df_filtrado["V"].var()

plt.plot([alcance,alcance],[0,meseta],color = 'red', label="Range", linestyle='dashed')

plt.plot([0,alcance*2],[meseta,meseta],color = 'orange',label = 'Statistics Variance', linestyle='dashed')



x = np.arange(0,alcance,1)
y = ((1.5*(x/alcance)) - (0.5*(x/alcance)**3))*meseta
plt.plot(x,y, color = 'red')
plt.xlabel('Lag distance (m)')
plt.ylabel('Spatial variance')
plt.ylim(0,0.5)
plt.xlim(0,400)
cbar = plt.colorbar()
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
handles, labels = plt.gca().get_legend_handles_labels()
plt.gca().legend(handles[::], labels[::])
plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/variograma_modelo2.png", dpi=300)

plt.show()

# %%
vario_kri = GSLIB.make_variogram(nug=0.0,nst=1,it1=1,cc1=meseta,azi1=0,hmaj1=200,hmin1=200) #ajuste con un unico modelo esférico
# Out:
#  make_variogram Warning: sill does not sum to 1.0, do not use in simulation

# %%
nx = 100; ny=50; xsiz=10; ysiz=10; xmn=0; ymn= 0; ndmax=20; ndmin=1;radius=200; 

ktype=1; skmean=0; nxdis=1; nydis=1; tmin=-9999; tmax=9999

kmap, vmap = geostats.kb2d(df_filtrado, "X", "Y", "V", tmin, tmax, nx, xmn, xsiz, ny, ymn, ysiz, nxdis, nydis, ndmin, ndmax, radius, ktype, skmean, vario_kri)
# Out:
#   Estimated   5000 blocks
#       average   1.9716064651814784  variance  0.18067696724712734

# %%
xmin = 0; ymin =0;                                          # grid origin

xmax = 1000; ymax = 500    # calculate the extent of model

# %%
df_kmap = pd.DataFrame(kmap) #se pasan los valores estimados al dataframe de la simulación 
df_vmap = pd.DataFrame(vmap) #se pasan los valores estimados al dataframe de la simulación 

df_vmap = df_vmap.stack().reset_index().rename(columns={"level_0": "North [Y]", "level_1": "East[X]", 0:"Var"})
df_kmap = df_kmap.stack().reset_index().rename(columns={"level_0": "North [Y]", "level_1": "East[X]", 0:"Ore grade"})

df["Var"] = df_vmap["Var"]
df["V_OK"]= df_kmap["Ore grade"]
df.head()
# Out:
#       X      Y         V       Var     V1_OK       GEO    VA_RNA      V_OK
# 0   0.0  490.0  1.425655  0.187132  8.497820  8.497820  1.092430  1.062005
# 1  10.0  490.0  1.398962  0.152383  7.567427  7.567427  0.975693  0.996280
# 2  20.0  490.0  1.188708  0.116073  6.920906  6.920906  0.930960  0.929009
# 3  30.0  490.0  0.992036  0.078479  6.337004  6.337004  0.861693  0.867346
# 4  40.0  490.0  0.680945  0.039985  6.025129  6.025129  0.796195  0.839161

# %%
df["V_OK"].describe().T
# Out:
# count    5000.000000
# mean        1.971606
# std         0.425104
# min         0.000000
# 25%         1.686157
# 50%         1.946080
# 75%         2.233815
# max         3.546454
# Name: V_OK, dtype: float64

# %%
df_vmap = df_vmap.stack().reset_index().rename(columns={"level_0": "North [Y]", "level_1": "East[X]", 0:"Var"})
df.head()
# Out:
#       X      Y         V       Var     V1_OK       GEO    VA_RNA      V_OK
# 0   0.0  490.0  1.425655  0.187132  8.497820  8.497820  1.092430  1.062005
# 1  10.0  490.0  1.398962  0.152383  7.567427  7.567427  0.975693  0.996280
# 2  20.0  490.0  1.188708  0.116073  6.920906  6.920906  0.930960  0.929009
# 3  30.0  490.0  0.992036  0.078479  6.337004  6.337004  0.861693  0.867346
# 4  40.0  490.0  0.680945  0.039985  6.025129  6.025129  0.796195  0.839161

# %%
marker_size=16
plt.figure(figsize=(8.2, 4.2))
plt.scatter(df["X"], df["Y"], marker_size, df["V_OK"], cmap = cmap, marker="s")
#plt.title("Ore Grade Estimated OK")
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.yticks(range(0, 501, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.title("OK")
plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/OK_case1_result.png", dpi=300)

plt.show()

# %%
marker_size=16
plt.figure(figsize=(8.2, 4.2))
plt.scatter(df["X"], df["Y"], marker_size, df["Var"], cmap = cmap, marker="s")
#plt.title("Ore Grade Estimated OK")
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('North [Y]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.yticks(range(0, 501, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 0.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label("%$^2$", labelpad=+1, fontsize=12)
plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/var_escenario2_caso1.png", dpi=300)

plt.show()

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt
x = df["V_OK"]
y = df["V"] 

# Suponiendo que x e y son arrays de NumPy o listas
# Si son series de pandas, puedes convertirlas usando: x = x.values, y = y.values

# Calcular el coeficiente de correlación lineal (R)
correlation_coefficient = np.corrcoef(x, y)[0, 1]

# Calcular el coeficiente de determinación (R^2)
r2 = r2_score(y, x)

# Calcular el error cuadrático medio (MSE)
mse = mean_squared_error(y, x)

# Calcular la raíz del error cuadrático medio (RMSE)
rmse = sqrt(mse)

# Calcular el error absoluto medio (MAE)
mae = mean_absolute_error(y, x)

print(f"Coeficiente de correlación lineal (R): {correlation_coefficient}")
print(f"Coeficiente de determinación (R^2): {r2}")
print(f"Error cuadrático medio (MSE): {mse}")
print(f"Raíz del error cuadrático medio (RMSE): {rmse}")
print(f"Error absoluto medio (MAE): {mae}")
# Out:
# Coeficiente de correlación lineal (R): 0.6414807125432525
# Coeficiente de determinación (R^2): 0.39157755581325726
# Error cuadrático medio (MSE): 0.18404778936648972
# Raíz del error cuadrático medio (RMSE): 0.42900791294157936
# Error absoluto medio (MAE): 0.3106666661303056

# %%
x = df["V"] 
y = df["V_OK"] 
slope, intercept = np.polyfit(x, y, 1)
regression_line = slope * x + intercept
r2 = r2_score(y, regression_line)
r = np.corrcoef(x, y)[0, 1]

fig = plt.figure(figsize=(5,4))
plt.scatter(x, y, color='blue', s=5, label='Data Points')
#plt.title("Validation OK", fontsize=12)
plt.plot(x, regression_line, color='red', label='Regression Line')
plt.text(0.5,3.2, 'R = {:.2f}, R\u00b2 = {:.2f}'.format(r, r2))
plt.xlabel("Ore grade")
plt.ylabel("Ore grade estimated")
plt.xlim((-0.3,3.9))
plt.ylim((-0.3,3.9))
#plt.savefig("C:/Users/nubem/Documents/NUBEMINERA_2020/GSLIB_FOLDER/data/dh_validation_ok_10percent.png", dpi=300)
# Out:
# (-0.3, 3.9)

# %% [markdown]
# # COMPARACIÓN DISTRIBUCIONES MLP VS OK

# %%
# Seleccionar las columnas relevantes para la comparación
selected_columns = ["V", "VA_RNA", "V_OK"]
df_selected = df[selected_columns]

# Etiquetas personalizadas y colores
custom_labels = {
    "VA_RNA": "NN",
    "V_OK": "OK",
    "V": "Original"
}
custom_colors = {
    "VA_RNA": "red",
    "V_OK": "blue",
    "V": "black"
}

marker_size = 2  # Cambia este valor según lo desees

# Genera el gráfico de distribución acumulada en forma de curva
plt.figure(figsize=(8.2, 4.2))
for column in df_selected.columns[1:]:
    values = np.sort(df_selected[column])
    cumulative_percentiles = np.arange(1, len(values) + 1) / len(values) * 100
    plt.plot(values, cumulative_percentiles, marker='o', markersize=marker_size, label=custom_labels[column], color=custom_colors[column])

# Agregar la variable "V" al gráfico
values_v = np.sort(df_selected["V"])
cumulative_percentiles_v = np.arange(1, len(values_v) + 1) / len(values_v) * 100
plt.plot(values_v, cumulative_percentiles_v, marker='o', markersize=marker_size, label=custom_labels["V"], color=custom_colors["V"])

plt.xlabel("Grade (%)")
plt.ylabel("Cumlative percentage (%)")
plt.legend()
plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/distribuciones_Caso_1_escenario2.png", dpi=300)

plt.show()

# %% [markdown]
# # Modelo Hibrido MLP-OK

# %%
df.head()
# Out:
#       X      Y         V       Var     V1_OK       GEO    VA_RNA      V_OK
# 0   0.0  490.0  1.425655  0.187132  8.497820  8.497820  1.092430  1.062005
# 1  10.0  490.0  1.398962  0.152383  7.567427  7.567427  0.975693  0.996280
# 2  20.0  490.0  1.188708  0.116073  6.920906  6.920906  0.930960  0.929009
# 3  30.0  490.0  0.992036  0.078479  6.337004  6.337004  0.861693  0.867346
# 4  40.0  490.0  0.680945  0.039985  6.025129  6.025129  0.796195  0.839161

# %%
#Estandarización de la varianza:
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

df["Var_scaled"] = scaler.fit_transform(df[["Var"]])

# %%
# Definir el rango de valores de b
b_values = np.arange(0.1, 2.1, 0.1)

# Inicializar listas para almacenar los valores de R para cada escenario de b
r_values = []

# Crear una figura para el gráfico
fig = plt.figure(figsize=(6, 4.2))

# Iterar a través de los valores de b y calcular los valores de R correspondientes
for b in b_values:
    df["b_05"] = df["Var_scaled"] ** b
    df["mlp_ok"] = ((df["VA_RNA"]*df["b_05"])+((1-df["b_05"])*df["V_OK"]))
    
    x = df["V"]
    y = df["mlp_ok"]
    r = np.corrcoef(x, y)[0, 1]
    
    r_values.append(r)

# Crear el gráfico de líneas para los valores de R
plt.plot(b_values, r_values, marker='o', linestyle='-', color='blue')
plt.xlabel("Weight coefficient (b)")
plt.ylabel("Linear correlation coefficient (R)")
plt.title("b curve FCM scenario III")
plt.xticks(np.arange(0.1, 2.1, 0.2))  # Ajustar las marcas en el eje X para que se muestren cada unidad
plt.grid(False)
plt.xlim((0,2.1))
#plt.ylim((0.7, 0.76))
plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/RFBNN_python/hibrid_figures/bcurve_e3.png", dpi=300)

plt.show()

# %%
df["b_05"] = df["Var_scaled"]**0.3 #se crea un nuevo peso (wi) que depende de var**0.5

# %%
df["mlp_ok"] = ((df["VA_RNA"]*df["b_05"])+((1-df["b_05"])*df["V_OK"])) #Estimación Hibrida con nuevo peso b=0.5

# %%
x = df["V"] 
y = df["mlp_ok"] 
slope, intercept = np.polyfit(x, y, 1)
regression_line = slope * x + intercept
r2 = r2_score(y, regression_line)
r = np.corrcoef(x, y)[0, 1]

fig = plt.figure(figsize=(5,4))
plt.scatter(x, y, color='blue', s=5, label='Data Points')
#plt.title("Validation OK", fontsize=12)
plt.plot(x, regression_line, color='red', label='Regression Line')
plt.text(0.5,3.2, 'R = {:.2f}, R\u00b2 = {:.2f}'.format(r, r2))
plt.xlabel("Ore grade")
plt.ylabel("Ore grade estimated")
plt.xlim((-0.3,3.9))
plt.ylim((-0.3,3.9))
#plt.savefig("C:/Users/nubem/Documents/NUBEMINERA_2020/GSLIB_FOLDER/data/dh_validation_ok_10percent.png", dpi=300)
# Out:
# (-0.3, 3.9)

# %%
marker_size=15
fig = plt.figure(figsize=(16,4))
plt.subplot(121)
plt.scatter(df["X"], df["Y"], marker_size, df["b_05"], cmap = plt.cm.jet, marker="s")
#plt.title("SGSIM+Affine Correction", fontsize=20)
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 1)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
plt.subplot(122)
plt.scatter(df["X"], df["Y"], marker_size, df["mlp_ok"], cmap=plt.cm.jet, marker="s")
#plt.title("Ore Grade Estimated OK")
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('Measurement', labelpad=+1, fontsize=12)
#plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/RFBNN_python/hibrid_figures/kriging.png", dpi=300)

plt.show()

# %%
marker_size=16
plt.figure(figsize=(8.2, 4.2))
plt.scatter(df["X"], df["Y"], marker_size, df["mlp_ok"], cmap=plt.cm.jet, marker="s")
#plt.title("Ore Grade Estimated OK")
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.yticks(range(0, 501, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.title("FCM")
plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('%', labelpad=+1, fontsize=12)
plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/combinado_Flexible_caso1_esce3.png", dpi=300)

plt.show()

# %%
import numpy as np
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt
x = df["mlp_ok"]
y = df["V"] 

# Suponiendo que x e y son arrays de NumPy o listas
# Si son series de pandas, puedes convertirlas usando: x = x.values, y = y.values

# Calcular el coeficiente de correlación lineal (R)
correlation_coefficient = np.corrcoef(x, y)[0, 1]

# Calcular el coeficiente de determinación (R^2)
r2 = r2_score(y, x)

# Calcular el error cuadrático medio (MSE)
mse = mean_squared_error(y, x)

# Calcular la raíz del error cuadrático medio (RMSE)
rmse = sqrt(mse)

# Calcular el error absoluto medio (MAE)
mae = mean_absolute_error(y, x)

print(f"Coeficiente de correlación lineal (R): {correlation_coefficient}")
print(f"Coeficiente de determinación (R^2): {r2}")
print(f"Error cuadrático medio (MSE): {mse}")
print(f"Raíz del error cuadrático medio (RMSE): {rmse}")
print(f"Error absoluto medio (MAE): {mae}")
# Out:
# Coeficiente de correlación lineal (R): 0.7938667113634814
# Coeficiente de determinación (R^2): 0.6301129856108061
# Error cuadrático medio (MSE): 0.1118908218527312
# Raíz del error cuadrático medio (RMSE): 0.33450085478624897
# Error absoluto medio (MAE): 0.25289941086920625

# %%
df.to_csv("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/result_ok_mlp_case1_ESCENARIO_B.csv")

# %% [markdown]
# # MODELO RIGIDO:

# %%
df.head()
# Out:
#       X      Y         V       Var     V1_OK       GEO    VA_RNA      V_OK  \
# 0   0.0  490.0  1.425655  0.187132  8.497820  8.497820  1.092430  1.062005
# 1  10.0  490.0  1.398962  0.152383  7.567427  7.567427  0.975693  0.996280
# 2  20.0  490.0  1.188708  0.116073  6.920906  6.920906  0.930960  0.929009
# 3  30.0  490.0  0.992036  0.078479  6.337004  6.337004  0.861693  0.867346
# 4  40.0  490.0  0.680945  0.039985  6.025129  6.025129  0.796195  0.839161
#
#    Var_scaled      b_05    mlp_ok
# 0    0.315466  0.707434  1.083528
# 1    0.256886  0.665154  0.982587
# 2    0.195676  0.613001  0.930205
# 3    0.132300  0.545089  0.864264
# 4    0.067407  0.445257  0.820030

# %%
columnas = ["X","Y", "V", "VA_RNA", "Var", "V_OK"]
df_rigido = df[columnas]
df_rigido.head()
# Out:
#       X      Y         V    VA_RNA       Var      V_OK
# 0   0.0  490.0  1.425655  1.092430  0.187132  1.062005
# 1  10.0  490.0  1.398962  0.975693  0.152383  0.996280
# 2  20.0  490.0  1.188708  0.930960  0.116073  0.929009
# 3  30.0  490.0  0.992036  0.861693  0.078479  0.867346
# 4  40.0  490.0  0.680945  0.796195  0.039985  0.839161

# %%
# Crear la nueva columna 'rigid' con valores basados en la condición
df_rigido['rigid'] = df_rigido.apply(lambda row: row['VA_RNA'] if row['Var'] > 0.25 else row['V_OK'], axis=1)
df_rigido.head()
# Out:
# C:\TEMP\ipykernel_10228\3447138609.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rigido['rigid'] = df_rigido.apply(lambda row: row['VA_RNA'] if row['Var'] > 0.25 else row['V_OK'], axis=1)
#       X      Y         V    VA_RNA       Var      V_OK     rigid
# 0   0.0  490.0  1.425655  1.092430  0.187132  1.062005  1.062005
# 1  10.0  490.0  1.398962  0.975693  0.152383  0.996280  0.996280
# 2  20.0  490.0  1.188708  0.930960  0.116073  0.929009  0.929009
# 3  30.0  490.0  0.992036  0.861693  0.078479  0.867346  0.867346
# 4  40.0  490.0  0.680945  0.796195  0.039985  0.839161  0.839161

# %%
marker_size=15
fig = plt.figure(figsize=(8,4.2))

plt.scatter(df_rigido["X"], df_rigido["Y"], marker_size, df_rigido["Var"], cmap=plt.cm.jet, marker="s")
#plt.title("Ore Grade Estimated OK")
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
#plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('Measurement', labelpad=+1, fontsize=12)
#plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/RFBNN_python/hibrid_figures/kriging.png", dpi=300)

plt.show()

# %%
marker_size=15
fig = plt.figure(figsize=(8,4.2))

plt.scatter(df_rigido["X"], df_rigido["Y"], marker_size, df_rigido["rigid"], cmap=plt.cm.jet, marker="s")
#plt.title("Ore Grade Estimated OK")
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 3.5)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('Measurement', labelpad=+1, fontsize=12)
#plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/combinado_rigido.png", dpi=300)

plt.show()

# %%
x = df_rigido["rigid"]
y = df_rigido["V"]

# Suponiendo que x e y son arrays de NumPy o listas
# Si son series de pandas, puedes convertirlas usando: x = x.values, y = y.values

# Calcular el coeficiente de correlación lineal (R)
correlation_coefficient = np.corrcoef(x, y)[0, 1]

# Calcular el coeficiente de determinación (R^2)
r2 = r2_score(y, x)

# Calcular el error cuadrático medio (MSE)
mse = mean_squared_error(y, x)

# Calcular la raíz del error cuadrático medio (RMSE)
rmse = sqrt(mse)

# Calcular el error absoluto medio (MAE)
mae = mean_absolute_error(y, x)

print(f"Coeficiente de correlación lineal (R): {correlation_coefficient}")
print(f"Coeficiente de determinación (R^2): {r2}")
print(f"Error cuadrático medio (MSE): {mse}")
print(f"Raíz del error cuadrático medio (RMSE): {rmse}")
print(f"Error absoluto medio (MAE): {mae}")
# Out:
# Coeficiente de correlación lineal (R): 0.7613214498101483
# Coeficiente de determinación (R^2): 0.5779459713636598
# Error cuadrático medio (MSE): 0.12767134366249294
# Raíz del error cuadrático medio (RMSE): 0.35731126999087637
# Error absoluto medio (MAE): 0.27423969307576873

# %%
df_rigido.describe().T
# Out:
#          count        mean         std           min         25%         50%  \
# X       5000.0  495.000000  288.689571  0.000000e+00  247.500000  495.000000
# Y       5000.0  245.000000  144.323130  0.000000e+00  120.000000  245.000000
# V       5000.0    2.000000    0.550055  9.669300e-02    1.642968    2.000339
# VA_RNA  5000.0    2.004151    0.463667  5.337577e-01    1.701616    2.012445
# Var     5000.0    0.151371    0.139740 -3.103517e-15    0.062866    0.098316
# V_OK    5000.0    1.971606    0.425104  0.000000e+00    1.686157    1.946080
# rigid   5000.0    1.978766    0.426020  0.000000e+00    1.693816    1.954807
#
#                75%         max
# X       742.500000  990.000000
# Y       370.000000  490.000000
# V         2.364052    3.931615
# VA_RNA    2.279066    3.710544
# Var       0.224373    0.593192
# V_OK      2.233815    3.546454
# rigid     2.235988    3.546454

# %%
df_rigido["FCM"] = df["mlp_ok"]
df_rigido.describe().T
# Out:
# C:\TEMP\ipykernel_10228\1322662230.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rigido["FCM"] = df["mlp_ok"]
#          count        mean         std           min         25%         50%  \
# X       5000.0  495.000000  288.689571  0.000000e+00  247.500000  495.000000
# Y       5000.0  245.000000  144.323130  0.000000e+00  120.000000  245.000000
# V       5000.0    2.000000    0.550055  9.669300e-02    1.642968    2.000339
# VA_RNA  5000.0    2.004151    0.463667  5.337577e-01    1.701616    2.012445
# Var     5000.0    0.151371    0.139740 -3.103517e-15    0.062866    0.098316
# V_OK    5000.0    1.971606    0.425104  0.000000e+00    1.686157    1.946080
# rigid   5000.0    1.978766    0.426020  0.000000e+00    1.693816    1.954807
# FCM     5000.0    1.979936    0.419331  3.677186e-29    1.694877    1.946276
#
#                75%         max
# X       742.500000  990.000000
# Y       370.000000  490.000000
# V         2.364052    3.931615
# VA_RNA    2.279066    3.710544
# Var       0.224373    0.593192
# V_OK      2.233815    3.546454
# rigid     2.235988    3.546454
# FCM       2.229791    3.546454

# %%
df45 = pd.read_csv("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Hybrid_model_test_2023/df_rigido_rbf.csv")
df45.head()
# Out:
#    Unnamed: 0     X      Y         V     V_RBF       Var      V_OK     rigid  \
# 0           0   0.0  490.0  1.425655  1.153469  0.187132  1.062005  1.062005
# 1           1  10.0  490.0  1.398962  1.085687  0.152383  0.996280  0.996280
# 2           2  20.0  490.0  1.188708  1.026588  0.116073  0.929009  0.929009
# 3           3  30.0  490.0  0.992036  0.980612  0.078479  0.867346  0.867346
# 4           4  40.0  490.0  0.680945  0.951440  0.039985  0.839161  0.839161
#
#       FCMe1
# 0  1.071107
# 1  1.002180
# 2  0.932745
# 3  0.869328
# 4  0.839671

# %%
df_rigido["V_RBF"] = df45["V_RBF"]
df_rigido["FCMe1"] = df45["FCMe1"]
df_rigido["rCMe1"] = df45["rigid"]

# %%
df78 = pd.read_csv("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Hybrid_model_test_2023/df_rigido_e2.csv")
df78.head()
# Out:
#    Unnamed: 0     X      Y         V    VA_RNA       Var      V_OK     rigid  \
# 0           0   0.0  490.0  1.425655  1.439603  0.187132  1.062005  1.062005
# 1           1  10.0  490.0  1.398962  1.422443  0.152383  0.996280  0.996280
# 2           2  20.0  490.0  1.188708  1.405215  0.116073  0.929009  0.929009
# 3           3  30.0  490.0  0.992036  1.392186  0.078479  0.867346  0.867346
# 4           4  40.0  490.0  0.680945  1.381803  0.039985  0.839161  0.839161
#
#       FCMe2    FCMe22
# 0  1.057828  1.099583
# 1  0.998826  1.024402
# 2  0.933845  0.947243
# 3  0.871895  0.876532
# 4  0.840795  0.841626

# %%
df_rigido["NNE2"] = df78["VA_RNA"]
df_rigido["FCME2"] = df78["FCMe22"]
df_rigido["RCME2"] = df78["rigid"]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Variables de interés
variables = ['V_RBF','NNE2','VA_RNA', 'rCMe1','RCME2','rigid','FCMe1','FCME2', 'FCM', 'V_OK']

# Cálculo de errores para cada variable
errores = {}
for variable in variables:
    errores[variable] = df_rigido['V'] - df_rigido[variable]

# Crear un gráfico de caja (boxplot) para comparar los errores
fig = plt.figure(figsize=(10,7))
sns.boxplot(data=pd.DataFrame(errores))
plt.xlabel('Methods and scenarios')
plt.ylabel('Absolute Error')

plt.xticks(rotation=45)
plt.gca().set_xticklabels(['NN-E1','NN-E2','NN-E3','RCM-E1','RCM-E2','RCM-E3','FCM-E1','FCM-E2','FCM-E3', 'OK'])  # Cambia los nombres en el eje x
plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/resultados_scenario3.png", dpi=300)

plt.show()

# %%
df_rigido.head()
# Out:
#       X      Y         V    VA_RNA       Var      V_OK     rigid       FCM  \
# 0   0.0  490.0  1.425655  1.092430  0.187132  1.062005  1.062005  1.065033
# 1  10.0  490.0  1.398962  0.975693  0.152383  0.996280  0.996280  0.994921
# 2  20.0  490.0  1.188708  0.930960  0.116073  0.929009  0.929009  0.929084
# 3  30.0  490.0  0.992036  0.861693  0.078479  0.867346  0.867346  0.867247
# 4  40.0  490.0  0.680945  0.796195  0.039985  0.839161  0.839161  0.838966
#
#       V_RBF      NNE2     FCME2     RCME2     FCMe1     rCMe1
# 0  1.153469  1.439603  1.099583  1.062005  1.071107  1.062005
# 1  1.085687  1.422443  1.024402  0.996280  1.002180  0.996280
# 2  1.026588  1.405215  0.947243  0.929009  0.932745  0.929009
# 3  0.980612  1.392186  0.876532  0.867346  0.869328  0.867346
# 4  0.951440  1.381803  0.841626  0.839161  0.839671  0.839161

# %%
df_rigido["errorrcme3"] = (df_rigido["V"]-df_rigido["rigid"])**2

# %%
marker_size=15
fig = plt.figure(figsize=(8,4.2))

plt.scatter(df_rigido["X"], df_rigido["Y"], marker_size, df_rigido["errorrcme3"], cmap=plt.cm.jet, marker="s")
plt.title("RCM-E3")
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 2)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('Square error', labelpad=+1, fontsize=12)
plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/errores_rcme3.png", dpi=300)

plt.show()

# %%
df_rigido["errorfcme3"] = (df_rigido["V"]-df_rigido["FCM"])**2

# %%
marker_size=15
fig = plt.figure(figsize=(8,4.2))

plt.scatter(df_rigido["X"], df_rigido["Y"], marker_size, df_rigido["errorfcme3"], cmap=plt.cm.jet, marker="s")
plt.title("FCM-E3")
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 2)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('Square error', labelpad=+1, fontsize=12)
plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/errores_fcme3.png", dpi=300)

plt.show()

# %%
df_rigido["errorrna"] = (df_rigido["V"]-df_rigido["VA_RNA"])**2

marker_size=15
fig = plt.figure(figsize=(8,4.2))

plt.scatter(df_rigido["X"], df_rigido["Y"], marker_size, df_rigido["errorrna"], cmap=plt.cm.jet, marker="s")
plt.title("NN-E3")
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 2)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('Square error', labelpad=+1, fontsize=12)
plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/errores_red.png", dpi=300)

plt.show()

# %%
df_rigido["errorok"] = (df_rigido["V"]-df_rigido["V_OK"])**2

marker_size=15
fig = plt.figure(figsize=(8,4.2))

plt.scatter(df_rigido["X"], df_rigido["Y"], marker_size, df_rigido["errorok"], cmap=plt.cm.jet, marker="s")
plt.title("OK")
plt.xlabel('East [X]', fontsize=12)
plt.ylabel('Elevation [Z]', fontsize=12)
plt.xticks(range(0, 1001, 100), fontsize=12)
plt.grid(False)
cbar = plt.colorbar()
plt.clim(0, 2)
cbar.ax.tick_params(labelsize=12)
cbar.set_label('Square error', labelpad=+1, fontsize=12)
plt.savefig("C:/Users/nubem/Desktop/TESIS DOCTORAL 2023-2024/Tesis_parte_3/Figuras/errores_ok.png", dpi=300)

plt.show()

# %%
df_rigido.describe().T
# Out:
#              count        mean         std           min         25%  \
# X           5000.0  495.000000  288.689571  0.000000e+00  247.500000
# Y           5000.0  245.000000  144.323130  0.000000e+00  120.000000
# V           5000.0    2.000000    0.550055  9.669300e-02    1.642968
# VA_RNA      5000.0    2.004151    0.463667  5.337577e-01    1.701616
# Var         5000.0    0.151371    0.139740 -3.103517e-15    0.062866
# V_OK        5000.0    1.971606    0.425104  0.000000e+00    1.686157
# rigid       5000.0    1.978766    0.426020  0.000000e+00    1.693816
# FCM         5000.0    1.979936    0.419331  3.677186e-29    1.694877
# V_RBF       5000.0    1.927486    0.427255  9.001835e-01    1.643527
# NNE2        5000.0    1.984730    0.430653  6.517788e-01    1.706716
# FCME2       5000.0    1.994297    0.405925  5.454862e-29    1.723909
# RCME2       5000.0    2.004366    0.415803  0.000000e+00    1.723120
# FCMe1       5000.0    1.959334    0.416310  4.505023e-29    1.665674
# rCMe1       5000.0    1.947449    0.420989  0.000000e+00    1.645920
# errorfcme3  5000.0    0.136693    0.204934  0.000000e+00    0.008554
# errorok     5000.0    0.184048    0.384454  0.000000e+00    0.009073
# errorrna    5000.0    0.119991    0.183916  5.548514e-11    0.009324
# errorrcme3  5000.0    0.127671    0.188283  0.000000e+00    0.008275
#
#                    50%         75%         max
# X           495.000000  742.500000  990.000000
# Y           245.000000  370.000000  490.000000
# V             2.000339    2.364052    3.931615
# VA_RNA        2.012445    2.279066    3.710544
# Var           0.098316    0.224373    0.593192
# V_OK          1.946080    2.233815    3.546454
# rigid         1.954807    2.235988    3.546454
# FCM           1.946276    2.229791    3.546454
# V_RBF         1.819701    2.171063    3.242504
# NNE2          1.955750    2.245511    3.376422
# FCME2         1.963823    2.231081    3.546454
# RCME2         1.970136    2.261545    3.546454
# FCMe1         1.907242    2.216374    3.546454
# rCMe1         1.877472    2.215014    3.546454
# errorfcme3    0.052252    0.177477    1.638482
# errorok       0.056816    0.193929    5.934047
# errorrna      0.044401    0.147728    1.804844
# errorrcme3    0.049995    0.169533    1.804844
